# %%
import pandas as pd

df = pd.read_csv("../../02_Data/processed/final_gamefound_list.csv")
rewards_df = pd.read_csv("../../02_Data/processed/final_rewards.csv")

# %%
df
# Out:
#                                            name  projectID  \
# 0    We Played God - A Survival Miniatures Game       5787
# 1                                     CARNIVORE       6481
# 2                                1809: Talavera       8024
# 3                                    Comber Cat       8225
# 4                    Jano - A Pawsome Adventure       5995
# ..                                          ...        ...
# 483                                    Tectonia       2109
# 484                              Invasion Cards       2149
# 485                                       MOOGH       1919
# 486              Crossroads Inn: The Board Game       1143
# 487         Goldenstar: The Galactic Tournament       1325
#
#                 creator  creatorID  \
# 0    Black Site Studios       5252
# 1            Buer Games       6737
# 2     Tactical Workshop       5141
# 3      Gamedolf Limited       8739
# 4                aszaki       7221
# ..                  ...        ...
# ...

# %%
rewards_df
# Out:
#                                        main_name  projectID  \
# 0     We Played God - A Survival Miniatures Game       5787
# 1     We Played God - A Survival Miniatures Game       5787
# 2     We Played God - A Survival Miniatures Game       5787
# 3     We Played God - A Survival Miniatures Game       5787
# 4     We Played God - A Survival Miniatures Game       5787
# ...                                          ...        ...
# 2102              Crossroads Inn: The Board Game       1143
# 2103         Goldenstar: The Galactic Tournament       1325
# 2104         Goldenstar: The Galactic Tournament       1325
# 2105         Goldenstar: The Galactic Tournament       1325
# 2106         Goldenstar: The Galactic Tournament       1325
#
#                                       anchorRelativeUrl  price  isDiscounted  \
# 0                         core-rules-physical-pdf-80323   60.0         False
# 1     eden-visitor-digital-pdfs-digital-survivor-stl...   62.0         False
# ...

# %%
rewards_join_df = pd.merge(
    rewards_df, 
    df[['projectID', 'currencySymbol']], 
    on='projectID', 
    how='left'
)

# %%
rewards_join_df
# Out:
#                                        main_name  projectID  \
# 0     We Played God - A Survival Miniatures Game       5787
# 1     We Played God - A Survival Miniatures Game       5787
# 2     We Played God - A Survival Miniatures Game       5787
# 3     We Played God - A Survival Miniatures Game       5787
# 4     We Played God - A Survival Miniatures Game       5787
# ...                                          ...        ...
# 2102              Crossroads Inn: The Board Game       1143
# 2103         Goldenstar: The Galactic Tournament       1325
# 2104         Goldenstar: The Galactic Tournament       1325
# 2105         Goldenstar: The Galactic Tournament       1325
# 2106         Goldenstar: The Galactic Tournament       1325
#
#                                       anchorRelativeUrl  price  isDiscounted  \
# 0                         core-rules-physical-pdf-80323   60.0         False
# 1     eden-visitor-digital-pdfs-digital-survivor-stl...   62.0         False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            488 non-null    object
#  1   projectID                       488 non-null    int64
#  2   creator                         488 non-null    object
#  3   creatorID                       488 non-null    int64
#  4   homeUrl                         488 non-null    object
#  5   currencySymbol                  488 non-null    object
#  6   campaignGoal                    488 non-null    float64
#  7   fundsGathered                   488 non-null    float64
#  8   backersCount                    488 non-null    int64
#  9   campaignStart                   488 non-null    object
#  10  campaignEnd                     488 non-null    object
#  11  phaseLabel                      488 non-null    object
# ...

# %%
rewards_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2107 entries, 0 to 2106
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   main_name              2107 non-null   object
#  1   projectID              2107 non-null   int64
#  2   anchorRelativeUrl      2107 non-null   object
#  3   price                  2107 non-null   float64
#  4   isDiscounted           2107 non-null   bool
#  5   effectivePrice         2107 non-null   float64
#  6   isFeatured             2107 non-null   bool
#  7   purchasedCopiesCount   2107 non-null   int64
#  8   backgroundUrl          2107 non-null   object
#  9   installmentCost        368 non-null    float64
#  10  installmentMinPayment  1200 non-null   float64
#  11  hasLimitedStock        2107 non-null   bool
#  12  productCanBePurchased  2107 non-null   bool
#  13  productID              2107 non-null   int64
# ...

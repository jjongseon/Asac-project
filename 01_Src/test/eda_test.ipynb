# %%
import pandas as pd

df = pd.read_csv("../02_Data/raw/gamefound_list.csv")

# %%
df.columns
# Out:
# Index(['name', 'projectID', 'creator', 'creatorID', 'homeUrl',
#        'currencySymbol', 'campaignGoal', 'fundsGathered', 'backersCount',
#        'campaignStart', 'campaignEnd', 'description', 'project_url',
#        'phaseLabel', 'enableBoardGameProperties', 'minPlayers', 'maxPlayers',
#        'minAge', 'playTime', 'playTimeDescription', 'playTimeUnit',
#        'pledgeManagerAvailability', 'fundedInSeconds', 'imageUrl',
#        'pledgeManagerSoftCloseDeadline', 'projectTags',
#        'enableShippingOnlyMode', 'originalType'],
#       dtype='object')

# %%
a_list = ['name', 'projectID', 'creator', 'creatorID', 'homeUrl',
       'currencySymbol', 'campaignGoal', 'fundsGathered', 'backersCount',
       'campaignStart', 'campaignEnd',
       'phaseLabel', 'enableBoardGameProperties', 'minPlayers', 'maxPlayers',
       'minAge', 'playTime', 'playTimeUnit',
       'fundedInSeconds', 'imageUrl',
       'pledgeManagerSoftCloseDeadline', 'projectTags',
       'originalType']

# %%
pd.set_option('display.max_columns', None)
df = df[a_list]

# %%
# 타플랫폼 펀딩 후 서약 관리 전용
df.loc[df['originalType']==0]
# Out:
#                                                name  projectID  \
# 440                                Escape From mars      10054
# 442                                  Beat Box Party      10072
# 446                            Travel Bug Card Game      11304
# 448   The Malice of Light Adventures Pledge Manager      10154
# 455                         The Cats of New Orleans       9843
# ...                                             ...        ...
# 2281                             GKR: Heavy Hitters         13
# 2282                               Endure The Stars         12
# 2283                        Star Scrappers: Cave-In          9
# 2284                                     Board&Dice          8
# 2285                       BATTALIA: The Stormgates          3
#
#                       creator  creatorID  \
# 440       Dark Frontier Games       4262
# 442       Boiling Point Games       8720
# 446              DominoTracks       8807
# ...

# %%
df.loc[df['originalType']==1]
# Out:
#                                      name  projectID             creator  \
# 0                              Bloodstone       8454    Druid City Games
# 2                                  A Life       9816       Skellig Games
# 3           Growing Season Deluxe Edition       8617           Undigital
# 4               Stonesaga Second Printing       9678    Open Owl Studios
# 5                          Beast: Ashfall       8330      Studio Midhall
# ...                                   ...        ...                 ...
# 2585    Spring and Autumn: Story of China       1446        Mr. B. Games
# 2586       Crossroads Inn: The Board Game       1143            Klabater
# 2587                            PACHAMAMA       1170             SitDown
# 2588         Taverns & Dragons (Canceled)       1314  Lord Raccoon Games
# 2589  Goldenstar: The Galactic Tournament       1325               Gindi
#
#       creatorID                                          homeUrl  \
# ...

# %%
df.loc[df['originalType']==1]['phaseLabel'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1402 entries, 0 to 2589
# Series name: phaseLabel
# Non-Null Count  Dtype
# --------------  -----
# 1402 non-null   object
# dtypes: object(1)
# memory usage: 21.9+ KB

# %%
df.loc[df['originalType']==1]['phaseLabel'].value_counts()
# Out:
# phaseLabel
# Upcoming                         389
# Pledge manager - Closed          322
# Pledge manager - Limited         148
# Crowdfunding - Canceled          136
# Crowdfunding - Unsuccessful      124
# Pledge manager - Open for all    112
# Late Pledge - Open for all        89
# Crowdfunding - Funded             42
# Crowdfunding                      39
# Late Pledge - Ended                1
# Name: count, dtype: int64

# %%
df.loc[df['originalType']==1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1402 entries, 0 to 2589
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            1402 non-null   object
#  1   projectID                       1402 non-null   int64
#  2   creator                         1402 non-null   object
#  3   creatorID                       1402 non-null   int64
#  4   homeUrl                         1402 non-null   object
#  5   currencySymbol                  1402 non-null   object
#  6   campaignGoal                    1381 non-null   float64
#  7   fundsGathered                   1402 non-null   float64
#  8   backersCount                    1402 non-null   int64
#  9   campaignStart                   1031 non-null   object
#  10  campaignEnd                     1181 non-null   object
#  11  phaseLabel                      1402 non-null   object
# ...

# %%
df.loc[(df['originalType']==1)&(df['phaseLabel']=="Pledge manager - Limited")]
# Out:
#                                                name  projectID  \
# 780   Wilderness - A Game of Survival (2nd Edition)       6314
# 781              PANDORA CELESTE: Pirates & Salvage       6415
# 782                                   LONG DARK SEA       3879
# 783                                      Colleagues       5539
# 784                       The Glasgow Train Robbery       6116
# ...                                             ...        ...
# 1624                                   Master Dater       1742
# 1637                                    Wild Realms       1341
# 1672                Total War: ROME: The Board Game       1346
# 1731     Masters of the Universe: Fields of Eternia        242
# 1836          Robinson Crusoe - Collector's Edition        881
#
#                           creator  creatorID  \
# 780                     FryxGames       7596
# 781                Guntower Games       3411
# 782                 DELUSIO GAMES       4380
# ...

# %%
df.loc[df['originalType']==1]['campaignGoal'].isnull().value_counts()
# Out:
# campaignGoal
# False    1381
# True       21
# Name: count, dtype: int64

# %% [markdown]
# rewardss

# %%
df2 = pd.read_csv("../02_Data/raw/rewards.csv")

# %%
df2
# Out:
#        Unnamed: 0                            main_name  projectID_id  \
# 0               0                           Bloodstone          8454
# 1               1                           Bloodstone          8454
# 2               2                           Bloodstone          8454
# 3               3                               Aeolis          8619
# 4               4                               Aeolis          8619
# ...           ...                                  ...           ...
# 11141       11141         Taverns & Dragons (Canceled)          1314
# 11142       11142  Goldenstar: The Galactic Tournament          1325
# 11143       11143  Goldenstar: The Galactic Tournament          1325
# 11144       11144  Goldenstar: The Galactic Tournament          1325
# 11145       11145  Goldenstar: The Galactic Tournament          1325
#
#                                                  raw_url  \
# 0      https://gamefound.com/api/projectContents/getR...
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'main_name', 'projectID_id', 'raw_url',
#        'anchorRelativeUrl', 'backgroundUrl', 'deliveryDateRemarks',
#        'estimatedDeliveryAt', 'hasDetails', 'isExposed', 'isMostPopular',
#        'purchasedCopiesCount', 'additionalInfoUrl', 'hasInstallmentsAvailable',
#        'installmentCost', 'installmentMinPayment', 'abstract', 'categoryID',
#        'effectivePrice', 'hasLimitedStock', 'hasRetailerAccess',
#        'hasSpecialAccess', 'imageUrl', 'isDigital', 'isDiscounted',
#        'isFeatured', 'name', 'price', 'productCanBePurchased',
#        'productCanBePurchasedDescription', 'productID', 'projectID',
#        'remainingStockLimit', 'url', 'productState'],
#       dtype='object')

# %%
b_list = [ 'main_name', 'projectID',
       'anchorRelativeUrl', 'backgroundUrl',
       'purchasedCopiesCount',
       'installmentCost', 'installmentMinPayment',
        'hasLimitedStock',
       'isDiscounted', 'price', 'effectivePrice',
       'isFeatured',   'productCanBePurchased',
       'productID',
       'remainingStockLimit']

# %%
df2["hasDetails"]==tru
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11141    False
# 11142    False
# 11143    False
# 11144    False
# 11145    False
# Name: hasDetails, Length: 11146, dtype: bool

# %% [markdown]
# comment

# %%
df3 = pd.read_csv("../02_Data/raw/gamefound_ALL_comments_Hierarchical.csv")

# %%
df3
# Out:
#                                 project_name  comment_id  parent_id  \
# 0                  Stonesaga Second Printing     2598484        NaN
# 1                  Stonesaga Second Printing     2611664        NaN
# 2                  Stonesaga Second Printing     2611763  2611664.0
# 3                  Stonesaga Second Printing     2611527        NaN
# 4                  Stonesaga Second Printing     2609072        NaN
# ...                                      ...         ...        ...
# 1585624  Goldenstar: The Galactic Tournament      115587   115520.0
# 1585625  Goldenstar: The Galactic Tournament      115489        NaN
# 1585626  Goldenstar: The Galactic Tournament      118641   115489.0
# 1585627  Goldenstar: The Galactic Tournament      115326        NaN
# 1585628  Goldenstar: The Galactic Tournament      115344   115326.0
#
#          depth_level  author_id       author_name  creator_id  \
# 0                  0     244541  BrendanMcCaskell           1
# ...

# %%
df3.columns
# Out:
# Index(['project_name', 'comment_id', 'parent_id', 'depth_level', 'author_id',
#        'author_name', 'creator_id', 'is_pledge_master', 'is_backer',
#        'backer_number', 'is_prior_backer', 'is_pathfinder', 'has_children',
#        'children_count', 'text', 'created_at', 'likes'],
#       dtype='object')

# %%
c_list = ['project_name', 'comment_id', 'parent_id', 'depth_level', 'author_id',
       'author_name', 'creator_id', 'is_pledge_master', 'is_backer',
       'is_prior_backer', 'is_pathfinder', 'has_children',
       'children_count', 'text', 'created_at', 'likes']

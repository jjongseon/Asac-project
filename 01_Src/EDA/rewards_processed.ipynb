# %%
import pandas as pd

df = pd.read_csv("../../02_Data/processed/final_rewards_tags.csv")

# %%
df.rename(columns={"단품 여부": "single_item"}, inplace=True)

# %%
df
# Out:
#                                        main_name  projectID  \
# 0     We Played God - A Survival Miniatures Game       5787
# 1     We Played God - A Survival Miniatures Game       5787
# 2     We Played God - A Survival Miniatures Game       5787
# 3     We Played God - A Survival Miniatures Game       5787
# 4     We Played God - A Survival Miniatures Game       5787
# ...                                          ...        ...
# 2102              Crossroads Inn: The Board Game       1143
# 2103         Goldenstar: The Galactic Tournament       1325
# 2104         Goldenstar: The Galactic Tournament       1325
# 2105         Goldenstar: The Galactic Tournament       1325
# 2106         Goldenstar: The Galactic Tournament       1325
#
#                                       anchorRelativeUrl  price  isDiscounted  \
# 0                         core-rules-physical-pdf-80323   60.0         False
# 1     eden-visitor-digital-pdfs-digital-survivor-stl...   62.0         False
# ...

# %%
df.loc[df['single_item']==1]
# Out:
#                                        main_name  projectID  \
# 0     We Played God - A Survival Miniatures Game       5787
# 10                                     CARNIVORE       6481
# 17                                1809: Talavera       8024
# 19                                    Comber Cat       8225
# 20                    Jano - A Pawsome Adventure       5995
# ...                                          ...        ...
# 2092                                    Tectonia       2109
# 2094                              Invasion Cards       2149
# 2096                                       MOOGH       1919
# 2099              Crossroads Inn: The Board Game       1143
# 2104         Goldenstar: The Galactic Tournament       1325
#
#                                       anchorRelativeUrl  price  isDiscounted  \
# 0                         core-rules-physical-pdf-80323  60.00         False
# 10                          megapredator-digital-102621  57.00         False
# ...

# %%
len(set(df.loc[df['single_item']==1]['projectID']))
# Out:
# 484

# %%
for i in set(df['projectID']):
    if i not in set(df.loc[df['single_item']==1]['projectID']):
        print(i)

# %%
df.loc[df['single_item']==1]["projectID"].value_counts()
# Out:
# projectID
# 5787    1
# 1103    1
# 8475    1
# 6626    1
# 8150    1
#        ..
# 3119    1
# 3453    1
# 3695    1
# 3844    1
# 1325    1
# Name: count, Length: 484, dtype: int64

# %%
df=df.loc[df['single_item']==1]

# %%
df.to_csv("../../02_Data/processed/final_rewards_typical.csv", index=False, encoding="utf-8-sig")

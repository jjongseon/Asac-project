# %%
import pandas as pd

df = pd.read_csv("../../02_Data/raw/rewards.csv")

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                                     main_name  projectID_id  \
# 0  We Played God - A Survival Miniatures Game          5787
# 1  We Played God - A Survival Miniatures Game          5787
# 2  We Played God - A Survival Miniatures Game          5787
# 3  We Played God - A Survival Miniatures Game          5787
# 4  We Played God - A Survival Miniatures Game          5787
#
#                                              raw_url  \
# 0  https://gamefound.com/api/projectContents/getR...
# 1  https://gamefound.com/api/projectContents/getR...
# 2  https://gamefound.com/api/projectContents/getR...
# 3  https://gamefound.com/api/projectContents/getR...
# 4  https://gamefound.com/api/projectContents/getR...
#
#                                    anchorRelativeUrl  \
# 0                      core-rules-physical-pdf-80323
# 1  eden-visitor-digital-pdfs-digital-survivor-stl...
# 2  eden-visitor-physical-core-rules-survivor-mini...
# 3                   eden-hacker-digital-all-in-81322
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2107 entries, 0 to 2106
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   main_name                         2107 non-null   object
#  1   projectID_id                      2107 non-null   int64
#  2   raw_url                           2107 non-null   object
#  3   anchorRelativeUrl                 2107 non-null   object
#  4   backgroundUrl                     2107 non-null   object
#  5   deliveryDateRemarks               675 non-null    object
#  6   estimatedDeliveryAt               1868 non-null   object
#  7   hasDetails                        2107 non-null   bool
#  8   isExposed                         2107 non-null   bool
#  9   isMostPopular                     2107 non-null   bool
#  10  purchasedCopiesCount              2107 non-null   int64
#  11  additionalInfoUrl                 0 non-null      float64
# ...

# %%
df.columns
# Out:
# Index(['main_name', 'projectID_id', 'raw_url', 'anchorRelativeUrl',
#        'backgroundUrl', 'deliveryDateRemarks', 'estimatedDeliveryAt',
#        'hasDetails', 'isExposed', 'isMostPopular', 'purchasedCopiesCount',
#        'additionalInfoUrl', 'hasInstallmentsAvailable', 'installmentCost',
#        'installmentMinPayment', 'abstract', 'categoryID', 'effectivePrice',
#        'hasLimitedStock', 'hasRetailerAccess', 'hasSpecialAccess', 'imageUrl',
#        'isDigital', 'isDiscounted', 'isFeatured', 'name', 'price',
#        'productCanBePurchased', 'productCanBePurchasedDescription',
#        'productID', 'projectID', 'remainingStockLimit', 'url', 'productState'],
#       dtype='object')

# %%
df['isMostPopular'].value_counts()
# Out:
# False    2107
# Name: isMostPopular, dtype: int64

# %%
df['isExposed'].value_counts()
# Out:
# False    2107
# Name: isExposed, dtype: int64

# %%
df['isDigital'].value_counts()
# Out:
# False    2107
# Name: isDigital, dtype: int64

# %%
df['hasRetailerAccess'].value_counts()
# Out:
# False    2107
# Name: hasRetailerAccess, dtype: int64

# %%
df['isDigital'].value_counts()
# Out:
# False    2107
# Name: isDigital, dtype: int64

# %%
df['productCanBePurchasedDescription'].value_counts()
# Out:
# You can't add items to your pledge at this time.                                                            1480
# You can't add items to your pledge because this project is closed.                                           427
# You can't add items to your pledge because the Pledge Manager for this project hasn't been launched yet.     194
# Name: productCanBePurchasedDescription, dtype: int64

# %%
df['remainingStockLimit'].value_counts()
# Out:
# 0.0      217
# 1.0       26
# 100.0     13
# 2.0       12
# 5.0       10
#         ...
# 48.0       1
# 62.0       1
# 418.0      1
# 837.0      1
# 498.0      1
# Name: remainingStockLimit, Length: 121, dtype: int64

# %%
target_columns = ['main_name', 'projectID_id', 'anchorRelativeUrl', 'name', 'price', 'isDiscounted', 'effectivePrice',
        'isFeatured' , 'estimatedDeliveryAt',  'purchasedCopiesCount', 'abstract', 'categoryID', 
       'hasLimitedStock','productCanBePurchased', 'productCanBePurchasedDescription', 'remainingStockLimit',
       'isMostPopular','isDigital', 'isExposed', 'hasRetailerAccess', 'hasSpecialAccess',]

# %%
b_list = [ 'main_name', 'projectID', 'anchorRelativeUrl', 'price','isDiscounted', 'effectivePrice', 'isFeatured', 'purchasedCopiesCount',
        'installmentCost', 'installmentMinPayment', 'hasLimitedStock', 'productCanBePurchased',
       'productID','remainingStockLimit', 'backgroundUrl']

# %%
df = df[b_list]

# %%
df
# Out:
#                                        main_name  projectID  \
# 0     We Played God - A Survival Miniatures Game       5787
# 1     We Played God - A Survival Miniatures Game       5787
# 2     We Played God - A Survival Miniatures Game       5787
# 3     We Played God - A Survival Miniatures Game       5787
# 4     We Played God - A Survival Miniatures Game       5787
# ...                                          ...        ...
# 2102              Crossroads Inn: The Board Game       1143
# 2103         Goldenstar: The Galactic Tournament       1325
# 2104         Goldenstar: The Galactic Tournament       1325
# 2105         Goldenstar: The Galactic Tournament       1325
# 2106         Goldenstar: The Galactic Tournament       1325
#
#                                       anchorRelativeUrl  price  isDiscounted  \
# 0                         core-rules-physical-pdf-80323   60.0         False
# 1     eden-visitor-digital-pdfs-digital-survivor-stl...   62.0         False
# ...

# %%
df.to_csv("../../02_data/processed/final_rewards.csv", index=False, encoding="utf-8-sig")

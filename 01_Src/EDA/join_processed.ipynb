# %%
import pandas as pd
pd.set_option("display.max_columns",None)

list_df = pd.read_csv("../../02_Data/processed/final_gamefound_list.csv")
rewards_df = pd.read_csv("../../02_Data/processed/final_rewards_typical.csv")

# %%
list_df
# Out:
#                                            name  projectID  \
# 0    We Played God - A Survival Miniatures Game       5787
# 1                                     CARNIVORE       6481
# 2                                1809: Talavera       8024
# 3                                    Comber Cat       8225
# 4                    Jano - A Pawsome Adventure       5995
# ..                                          ...        ...
# 483                                    Tectonia       2109
# 484                              Invasion Cards       2149
# 485                                       MOOGH       1919
# 486              Crossroads Inn: The Board Game       1143
# 487         Goldenstar: The Galactic Tournament       1325
#
#                                            project_url             creator  \
# 0    https://gamefound.com:443/en/projects/black-si...  Black Site Studios
# 1    https://gamefound.com:443/en/projects/buer-gam...          Buer Games
# 2    https://gamefound.com:443/en/projects/tactical...   Tactical Workshop
# 3    https://gamefound.com:443/en/projects/gamedolf...    Gamedolf Limited
# 4    https://gamefound.com:443/en/projects/aszaki/j...              aszaki
# ..                                                 ...                 ...
# 483  https://gamefound.com:443/en/projects/hagen-be...          Hagen Behr
# 484  https://gamefound.com:443/en/projects/lawrence...       Lawrence Lyle
# 485  https://gamefound.com:443/en/projects/nuts-pub...    Nuts! Publishing
# 486  https://gamefound.com:443/en/projects/klabater...            Klabater
# 487  https://gamefound.com:443/en/projects/gindi/go...               Gindi
#
#      creatorID                                            homeUrl  \
# 0         5252  https://gamefound.com/creators/black-site-studios
# 1         6737          https://gamefound.com/creators/buer-games
# 2         5141   https://gamefound.com/creators/tactical-workshop
# 3         8739     https://gamefound.com/creators/gamedolflimited
# 4         7221              https://gamefound.com/creators/aszaki
# ..         ...                                                ...
# 483       2703          https://gamefound.com/creators/hagen-behr
# 484       2742       https://gamefound.com/creators/lawrence-lyle
# 485       2363     https://gamefound.com/creators/nuts-publishing
# 486       1510            https://gamefound.com/creators/klabater
# 487         64               https://gamefound.com/creators/gindi
#
#     currencySymbol  campaignGoal  fundsGathered  backersCount  \
# 0                $       10000.0      393538.44          1567
# 1                $       20000.0      247988.30          1075
# 2                $        7000.0       23091.47           215
# 3                $         300.0         645.66            12
# 4                €        1000.0        4042.67            89
# ..             ...           ...            ...           ...
# 483              €       20000.0        8001.00           113
# 484              €        9800.0          70.00             2
# 485              €       10000.0        6285.00           143
# 486              €       20000.0       13420.63           158
# 487              €       30000.0       10890.00           148
#
#             campaignStart               campaignEnd  \
# 0    2025-06-17T14:30:00Z   2025-07-19T00:50:35.25Z
# 1    2026-02-25T16:00:00Z  2026-03-31T15:57:23.953Z
# 2    2026-03-01T05:00:00Z      2026-04-01T05:00:00Z
# 3    2026-02-02T13:00:00Z      2026-03-02T13:00:00Z
# 4    2026-01-16T12:00:00Z      2026-02-28T12:00:00Z
# ..                    ...                       ...
# 483  2022-07-05T18:00:00Z      2022-07-26T18:00:00Z
# 484  2022-07-04T10:00:00Z      2022-08-03T21:00:00Z
# 485  2022-04-26T16:00:00Z      2022-05-12T16:00:00Z
# 486  2021-10-28T14:00:00Z      2021-11-30T15:00:00Z
# 487  2021-10-05T16:00:00Z      2021-10-29T16:00:00Z
#
#                       phaseLabel  enableBoardGameProperties  minPlayers  \
# 0        Pledge manager - Closed                      False         NaN
# 1        Pledge manager - Closed                       True         1.0
# 2        Pledge manager - Closed                       True         1.0
# 3        Pledge manager - Closed                       True         2.0
# 4        Pledge manager - Closed                       True         2.0
# ..                           ...                        ...         ...
# 483  Crowdfunding - Unsuccessful                       True         2.0
# 484  Crowdfunding - Unsuccessful                       True         2.0
# 485  Crowdfunding - Unsuccessful                       True         1.0
# 486  Crowdfunding - Unsuccessful                       True         2.0
# 487  Crowdfunding - Unsuccessful                       True         2.0
#
#      maxPlayers  minAge  playTime  playTimeUnit  fundedInSeconds  \
# 0           NaN     NaN       NaN             0              628
# 1           4.0    13.0      90.0             0             2716
# 2           2.0    12.0       8.0             1            56442
# 3           5.0     8.0      15.0             0          2409627
# 4           6.0     8.0      20.0             0            14439
# ..          ...     ...       ...           ...              ...
# 483         4.0    14.0     180.0             0                0
# 484         4.0     5.0      25.0             0                0
# 485         4.0    14.0      30.0             0                0
# 486         4.0    12.0     120.0             0                0
# 487         4.0    14.0      60.0             0                0
#
#                                               imageUrl  \
# 0    https://imgcdn.gamefound.com/projectimage/proj...
# 1    https://imgcdn.gamefound.com/projectimage/proj...
# 2    https://imgcdn.gamefound.com/projectimage/proj...
# 3    https://imgcdn.gamefound.com/projectimage/proj...
# 4    https://imgcdn.gamefound.com/projectimage/proj...
# ..                                                 ...
# 483  https://imgcdn.gamefound.com/projectimage/proj...
# 484  https://imgcdn.gamefound.com/projectimage/proj...
# 485  https://imgcdn.gamefound.com/projectimage/proj...
# 486  https://imgcdn.gamefound.com/projectimage/proj...
# 487  https://imgcdn.gamefound.com/projectimage/proj...
#
#     pledgeManagerSoftCloseDeadline  \
# 0             2026-06-02T15:00:00Z
# 1             2026-06-01T14:00:00Z
# 2                              NaN
# 3                              NaN
# 4             2026-06-11T13:00:00Z
# ..                             ...
# 483                            NaN
# 484                            NaN
# 485                            NaN
# 486                            NaN
# 487                            NaN
#
#                                            projectTags  originalType
# 0    Exploration, Horror, Modern, Science Fiction, ...             1
# 1    History, Strategy, Wargame, Action, Collectibl...             1
# 2                           History, Strategy, Wargame             1
# 3              Card Game, Strategy, Party game, Family             1
# 4    Strategy, Resource management, Family, Worker ...             1
# ..                                                 ...           ...
# 483  Strategy, Wargame, Dice Game, Area Control, Co...             1
# 484                           Fantasy, Strategy, Humor             1
# 485      Dice Game, Multiplayer, Competitive, Campaign             1
# 486         Fantasy, Strategy, Terrain Building, Humor             1
# 487       Science Fiction, Area Control, Deck Building             1
#
# [488 rows x 24 columns]

# %%
list_df['originalType'].value_counts()
# Out:
# originalType
# 1    488
# Name: count, dtype: int64

# %%
list_df.loc[list_df['creator']=="Gabe-Barrett"]
# Out:
#                                                   name  projectID  \
# 8                Drawing Dead [Solo Game of the Month]       6605
# 12             Mission: Drive [Solo Game of the Month]       6435
# 27             Storybook Saga [Solo Game of the Month]       6225
# 35             Dice Commandos [Solo Game of the Month]       6033
# 55                  Dicemancy [Solo Game of the Month]       5536
# 56               Knight Moves [Solo Game of the Month]       5730
# 71   Rome: Fate of an Empire (DELUXE) [Solo Game of...       5198
# 72                 Paranormal [Solo Game of the Month]       5197
# 82   Action Packed Double Feature [Solo Game of the...       5104
# 83          Small-Time Heroes [Solo Game of the Month]       4983
# 92                 Mech Bunny [Solo Game of the Month]       4777
# 117  Spooky Double Feature + Dieson Crusoe Reprint ...       4707
# 120  Hunted: North Pole (2nd Edition) [Solo Game of...       4543
# 126        7th Inning Stretch [Solo Game of the Month]       4459
# 143         The Cursed Castle [Solo Game of the Month]       4346
# 152  Okinawa: The Last Battle of World War II [Solo...       4212
# 158  Hunted: Mining Colony 415 (2nd Edition) [Solo ...       4078
# 170   Rome: Fate of an Empire [Solo Game of the Month]       3997
# 180             Dieson Crusoe [Solo Game of the Month]       3745
# 185  Hunted: Kobayashi Tower (2nd Edition) [Solo Ga...       3582
# 324     Hunted: Wode Ridge 2E [Solo Game of the Month]      10156
#
#                                            project_url       creator  \
# 8    https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 12   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 27   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 35   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 55   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 56   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 71   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 72   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 82   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 83   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 92   https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 117  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 120  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 126  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 143  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 152  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 158  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 170  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 180  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 185  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
# 324  https://gamefound.com:443/en/projects/gabe-bar...  Gabe-Barrett
#
#      creatorID                                      homeUrl currencySymbol  \
# 8          731  https://gamefound.com/creators/gabe-barrett              $
# 12         731  https://gamefound.com/creators/gabe-barrett              $
# 27         731  https://gamefound.com/creators/gabe-barrett              $
# 35         731  https://gamefound.com/creators/gabe-barrett              $
# 55         731  https://gamefound.com/creators/gabe-barrett              $
# 56         731  https://gamefound.com/creators/gabe-barrett              $
# 71         731  https://gamefound.com/creators/gabe-barrett              $
# 72         731  https://gamefound.com/creators/gabe-barrett              $
# 82         731  https://gamefound.com/creators/gabe-barrett              $
# 83         731  https://gamefound.com/creators/gabe-barrett              $
# 92         731  https://gamefound.com/creators/gabe-barrett              $
# 117        731  https://gamefound.com/creators/gabe-barrett              $
# 120        731  https://gamefound.com/creators/gabe-barrett              $
# 126        731  https://gamefound.com/creators/gabe-barrett              $
# 143        731  https://gamefound.com/creators/gabe-barrett              $
# 152        731  https://gamefound.com/creators/gabe-barrett              $
# 158        731  https://gamefound.com/creators/gabe-barrett              $
# 170        731  https://gamefound.com/creators/gabe-barrett              $
# 180        731  https://gamefound.com/creators/gabe-barrett              $
# 185        731  https://gamefound.com/creators/gabe-barrett              $
# 324        731  https://gamefound.com/creators/gabe-barrett              $
#
#      campaignGoal  fundsGathered  backersCount         campaignStart  \
# 8          5000.0       83466.02          2010  2025-10-28T15:00:00Z
# 12         5000.0       44548.95          1180  2025-09-30T15:00:00Z
# 27         5000.0       96449.02          2546  2025-08-26T15:00:00Z
# 35         5000.0       71116.85          1825  2025-07-22T15:00:00Z
# 55         5000.0       90856.86          2383  2025-04-15T15:00:00Z
# 56         5000.0       55777.24          1492  2025-05-20T15:00:00Z
# 71         5000.0      185224.27          3273  2025-03-11T15:00:00Z
# 72         5000.0       88246.33          2570  2025-02-11T16:00:00Z
# 82         5000.0       32954.47           926  2025-01-15T16:00:00Z
# 83         5000.0       88843.43          2032  2024-12-17T16:00:00Z
# 92         5000.0       70312.30          2093  2024-11-19T16:00:00Z
# 117        5000.0       52970.69          1429  2024-10-15T15:00:00Z
# 120        5000.0       22403.59           768  2024-09-17T15:00:00Z
# 126        5000.0       41192.09          1416  2024-08-13T15:00:00Z
# 143        5000.0       67673.49          2326  2024-07-16T15:00:00Z
# 152        5000.0       54929.43          1842  2024-06-11T15:00:00Z
# 158        5000.0       61939.14          2239  2024-05-14T15:00:00Z
# 170        5000.0       88961.75          2993  2024-04-09T15:00:00Z
# 180        5000.0       54509.76          1954  2024-02-13T16:00:00Z
# 185        5000.0       46620.21          1793  2024-01-09T16:00:00Z
# 324        5000.0       30498.67           925  2026-05-12T15:00:00Z
#
#                   campaignEnd               phaseLabel  \
# 8    2025-11-15T06:15:03.567Z  Pledge manager - Closed
# 12       2025-10-18T04:00:00Z  Pledge manager - Closed
# 27       2025-09-13T04:00:00Z  Pledge manager - Closed
# 35    2025-08-09T04:37:13.41Z  Pledge manager - Closed
# 55   2025-05-03T04:44:52.423Z  Pledge manager - Closed
# 56     2025-06-06T05:22:03.3Z  Pledge manager - Closed
# 71   2025-03-29T05:06:11.233Z  Pledge manager - Closed
# 72       2025-03-01T04:00:00Z  Pledge manager - Closed
# 82       2025-02-01T05:00:00Z  Pledge manager - Closed
# 83       2025-01-03T05:00:00Z  Pledge manager - Closed
# 92       2024-12-06T05:00:00Z  Pledge manager - Closed
# 117      2024-11-01T04:59:00Z  Pledge manager - Closed
# 120      2024-10-04T04:00:00Z  Pledge manager - Closed
# 126      2024-08-30T04:59:00Z  Pledge manager - Closed
# 143      2024-08-02T04:59:00Z  Pledge manager - Closed
# 152      2024-06-28T04:00:00Z  Pledge manager - Closed
# 158      2024-05-31T04:59:00Z  Pledge manager - Closed
# 170      2024-04-26T04:59:00Z  Pledge manager - Closed
# 180      2024-03-01T05:00:00Z  Pledge manager - Closed
# 185      2024-01-26T05:59:00Z  Pledge manager - Closed
# 324      2026-05-30T04:10:00Z    Crowdfunding - Funded
#
#      enableBoardGameProperties  minPlayers  maxPlayers  minAge  playTime  \
# 8                         True         1.0         1.0    14.0      45.0
# 12                        True         1.0         1.0    14.0      45.0
# 27                        True         NaN         NaN     NaN       NaN
# 35                        True         1.0         1.0    14.0      30.0
# 55                        True         1.0         1.0    14.0      45.0
# 56                        True         1.0         1.0    14.0      45.0
# 71                        True         1.0         1.0    14.0      60.0
# 72                        True         1.0         2.0    14.0      45.0
# 82                        True         1.0         1.0    14.0      20.0
# 83                        True         1.0         2.0     NaN      40.0
# 92                        True         1.0         1.0     NaN      40.0
# 117                       True         1.0         1.0    14.0      20.0
# 120                       True         1.0         2.0    14.0      20.0
# 126                       True         1.0         2.0    14.0      45.0
# 143                       True         1.0         1.0    14.0      30.0
# 152                       True         1.0         1.0    14.0      40.0
# 158                       True         1.0         2.0    14.0      20.0
# 170                       True         1.0         1.0    14.0      60.0
# 180                       True         1.0         1.0    12.0      30.0
# 185                       True         NaN         NaN     NaN       NaN
# 324                       True         1.0         2.0    14.0      45.0
#
#      playTimeUnit  fundedInSeconds  \
# 8               0             1444
# 12              0             3731
# 27              0             1267
# 35              0             1609
# 55              0             1052
# 56              0             1653
# 71              0              675
# 72              0             1214
# 82              0             2787
# 83              0             1002
# 92              0             1513
# 117             0             2091
# 120             0             5920
# 126             0             3718
# 143             0             1379
# 152             0             4005
# 158             0             2313
# 170             0             1681
# 180             0             3069
# 185             0             7462
# 324             0             2322
#
#                                               imageUrl  \
# 8    https://imgcdn.gamefound.com/projectimage/proj...
# 12   https://imgcdn.gamefound.com/projectimage/proj...
# 27   https://imgcdn.gamefound.com/projectimage/proj...
# 35   https://imgcdn.gamefound.com/projectimage/proj...
# 55   https://imgcdn.gamefound.com/projectimage/proj...
# 56   https://imgcdn.gamefound.com/projectimage/proj...
# 71   https://imgcdn.gamefound.com/projectimage/proj...
# 72   https://imgcdn.gamefound.com/projectimage/proj...
# 82   https://imgcdn.gamefound.com/projectimage/proj...
# 83   https://imgcdn.gamefound.com/projectimage/proj...
# 92   https://imgcdn.gamefound.com/projectimage/proj...
# 117  https://imgcdn.gamefound.com/projectimage/proj...
# 120  https://imgcdn.gamefound.com/projectimage/proj...
# 126  https://imgcdn.gamefound.com/projectimage/proj...
# 143  https://imgcdn.gamefound.com/projectimage/proj...
# 152  https://imgcdn.gamefound.com/projectimage/proj...
# 158  https://imgcdn.gamefound.com/projectimage/proj...
# 170  https://imgcdn.gamefound.com/projectimage/proj...
# 180  https://imgcdn.gamefound.com/projectimage/proj...
# 185  https://imgcdn.gamefound.com/projectimage/proj...
# 324  https://imgcdn.gamefound.com/projectimage/proj...
#
#     pledgeManagerSoftCloseDeadline  \
# 8                              NaN
# 12                             NaN
# 27                             NaN
# 35            2026-06-09T23:00:00Z
# 55            2026-06-09T16:00:00Z
# 56            2026-06-15T14:00:00Z
# 71            2026-06-09T18:00:00Z
# 72            2026-06-09T19:00:00Z
# 82            2026-06-13T16:00:00Z
# 83            2026-06-11T17:00:00Z
# 92            2026-06-13T07:00:00Z
# 117           2026-06-16T05:00:00Z
# 120           2026-06-16T01:00:00Z
# 126           2026-06-12T13:00:00Z
# 143           2026-06-10T06:00:00Z
# 152           2026-06-15T20:00:00Z
# 158           2026-06-14T10:00:00Z
# 170           2026-06-10T19:00:00Z
# 180           2026-06-14T07:00:00Z
# 185           2026-06-14T02:00:00Z
# 324                            NaN
#
#                                            projectTags  originalType
# 8                                            Card Game             1
# 12   Card Game, Strategy, Logical, Action, Video Ga...             1
# 27                       Fantasy, Card Game, Dice Game             1
# 35                Card Game, Modern, Dice Game, Action             1
# 55                     Card Game, Mythology, Dice Game             1
# 56                Card Game, Video Game Theme, Logical             1
# 71   Card Game, History, Strategy, Deck Building, E...             1
# 72                           Horror, Dice Game, Action             1
# 82                                           Card Game             1
# 83                     Card Game, Fantasy, Cooperative             1
# 92                    Card Game, Action, Deck Building             1
# 117                                  Card Game, Horror             1
# 120                    Card Game, Dice Game, Adventure             1
# 126          Card Game, Modern, Dice Game, Competitive             1
# 143                      Card Game, Fantasy, Dice Game             1
# 152            Card Game, Dice Game, Strategy, History             1
# 158  Card Game, Survival, Horror, Science Fiction, ...             1
# 170  Card Game, Strategy, History, Deck Building, C...             1
# 180  Survival, Exploration, Dice Game, Adventure, W...             1
# 185  Card Game, Modern, Cooperative, Action, Dice Game             1
# 324  Card Game, Adventure, Cooperative, Print and Play             1

# %%
list_df.columns
# Out:
# Index(['name', 'projectID', 'project_url', 'creator', 'creatorID', 'homeUrl',
#        'currencySymbol', 'campaignGoal', 'fundsGathered', 'backersCount',
#        'campaignStart', 'campaignEnd', 'phaseLabel',
#        'enableBoardGameProperties', 'minPlayers', 'maxPlayers', 'minAge',
#        'playTime', 'playTimeUnit', 'fundedInSeconds', 'imageUrl',
#        'pledgeManagerSoftCloseDeadline', 'projectTags', 'originalType'],
#       dtype='object')

# %%
# creatorID -> 그 당시 몇개 만들었는지
# currencySymbol + campaignGoal, fundsGathered -> 단위 통일 하나 -> 조인 후 해야함
# campaignEnd- campaignStart -> 기간 만들고
# campaignStart 댓글 가지고 오는 용(시작 후 1주일?2주일)
# 'playTime', 'playTimeUnit' -> 1일경우에 시간으로 표시됨 하나로 통일
# pledgeManagerSoftCloseDeadline 있으면 1 없으면 0 -> 방치했나 신경썼나?
# projectTags -> 인코딩 ㅇㅇ

a_list = ['projectID',  'creatorID', 
       'currencySymbol', 'campaignGoal', 'fundsGathered', 'backersCount',
       'campaignStart', 'campaignEnd', 'phaseLabel',
       'enableBoardGameProperties', 'minPlayers', 'maxPlayers', 'minAge',
       'playTime', 'playTimeUnit', 'fundedInSeconds',
       'pledgeManagerSoftCloseDeadline', 'projectTags']

# %%
list_df = list_df[a_list]
list_df.head()
# Out:
#    projectID  creatorID currencySymbol  campaignGoal  fundsGathered  \
# 0       5787       5252              $       10000.0      393538.44
# 1       6481       6737              $       20000.0      247988.30
# 2       8024       5141              $        7000.0       23091.47
# 3       8225       8739              $         300.0         645.66
# 4       5995       7221              €        1000.0        4042.67
#
#    backersCount         campaignStart               campaignEnd  \
# 0          1567  2025-06-17T14:30:00Z   2025-07-19T00:50:35.25Z
# 1          1075  2026-02-25T16:00:00Z  2026-03-31T15:57:23.953Z
# 2           215  2026-03-01T05:00:00Z      2026-04-01T05:00:00Z
# 3            12  2026-02-02T13:00:00Z      2026-03-02T13:00:00Z
# 4            89  2026-01-16T12:00:00Z      2026-02-28T12:00:00Z
#
#                 phaseLabel  enableBoardGameProperties  minPlayers  maxPlayers  \
# 0  Pledge manager - Closed                      False         NaN         NaN
# 1  Pledge manager - Closed                       True         1.0         4.0
# 2  Pledge manager - Closed                       True         1.0         2.0
# 3  Pledge manager - Closed                       True         2.0         5.0
# 4  Pledge manager - Closed                       True         2.0         6.0
#
#    minAge  playTime  playTimeUnit  fundedInSeconds  \
# 0     NaN       NaN             0              628
# 1    13.0      90.0             0             2716
# 2    12.0       8.0             1            56442
# 3     8.0      15.0             0          2409627
# 4     8.0      20.0             0            14439
#
#   pledgeManagerSoftCloseDeadline  \
# 0           2026-06-02T15:00:00Z
# 1           2026-06-01T14:00:00Z
# 2                            NaN
# 3                            NaN
# 4           2026-06-11T13:00:00Z
#
#                                          projectTags
# 0  Exploration, Horror, Modern, Science Fiction, ...
# 1  History, Strategy, Wargame, Action, Collectibl...
# 2                         History, Strategy, Wargame
# 3            Card Game, Strategy, Party game, Family
# 4  Strategy, Resource management, Family, Worker ...

# %%
list_df['projectTags'].value_counts()
# Out:
# projectTags
# Card Game                                                                   7
# History, Wargame, Strategy, Area Control, Asymmetric                        2
# Card Game, Strategy                                                         2
# Wargame, Strategy, History                                                  2
# History, Strategy, Wargame                                                  2
#                                                                            ..
# Strategy, Dice Game, Economic                                               1
# Science Fiction, History, RPG, Cooperative, Multiplayer, Campaign, TTRPG    1
# Card Game, Strategy, Humor, Educational, Asymmetric, Competitive, Family    1
# Card Game, Survival, Horror, Science Fiction, Adventure, Dexterity          1
# Science Fiction, Area Control, Deck Building                                1
# Name: count, Length: 477, dtype: int64

# %%
rewards_df
# Out:
#                                       main_name  projectID  \
# 0    We Played God - A Survival Miniatures Game       5787
# 1                                     CARNIVORE       6481
# 2                                1809: Talavera       8024
# 3                                    Comber Cat       8225
# 4                    Jano - A Pawsome Adventure       5995
# ..                                          ...        ...
# 479                                    Tectonia       2109
# 480                              Invasion Cards       2149
# 481                                       MOOGH       1919
# 482              Crossroads Inn: The Board Game       1143
# 483         Goldenstar: The Galactic Tournament       1325
#
#                                      anchorRelativeUrl  price  isDiscounted  \
# 0                        core-rules-physical-pdf-80323  60.00         False
# 1                          megapredator-digital-102621  57.00         False
# 2                     backers-copy-1809-talavera-99555  69.99          True
# 3                                     cat-lovers-99754  20.00         False
# 4                                jano-board-game-92756  25.00         False
# ..                                                 ...    ...           ...
# 479  tectonia-the-boardgame-with-all-unlocked-stret...  70.00         False
# 480                          the-evil-earthworm--26496  19.90          True
# 481                       moogh-the-basic-pledge-24022  36.00          True
# 482  crossroads-inn-the-board-game-standard-edition...  50.00         False
# 483                       goldenstar-core-pledge-17700  43.00         False
#
#      effectivePrice  isFeatured  purchasedCopiesCount  \
# 0             60.00       False                     0
# 1             57.00       False                     0
# 2             56.99       False                     0
# 3             20.00        True                     0
# 4             25.00        True                     0
# ..              ...         ...                   ...
# 479           70.00        True                     0
# 480           13.90       False                     0
# 481           23.00        True                     0
# 482           50.00       False                     0
# 483           43.00       False                     0
#
#                                          backgroundUrl  installmentCost  \
# 0    https://imgcdn.gamefound.com/productimage/proj...              NaN
# 1    https://imgcdn.gamefound.com/productimage/proj...             28.5
# 2    https://imgcdn.gamefound.com/productimage/proj...              NaN
# 3    https://imgcdn.gamefound.com/productimage/proj...              NaN
# 4    https://imgcdn.gamefound.com/productimage/proj...              NaN
# ..                                                 ...              ...
# 479  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 480  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 481  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 482  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 483  https://imgcdn.gamefound.com/productimage/proj...              NaN
#
#      installmentMinPayment  hasLimitedStock  productCanBePurchased  productID  \
# 0                     75.0            False                  False      80323
# 1                    100.0            False                  False     102621
# 2                      NaN            False                  False      99555
# 3                      NaN            False                  False      99754
# 4                      NaN            False                  False      92756
# ..                     ...              ...                    ...        ...
# 479                    NaN            False                  False      26743
# 480                    NaN            False                  False      26496
# 481                    NaN            False                  False      24022
# 482                    NaN            False                  False      19113
# 483                    NaN            False                  False      17700
#
#      remainingStockLimit  single_item
# 0                    NaN          1.0
# 1                    NaN          1.0
# 2                    NaN          1.0
# 3                    NaN          1.0
# 4                    NaN          1.0
# ..                   ...          ...
# 479                  NaN          1.0
# 480                  NaN          1.0
# 481                  NaN          1.0
# 482                  NaN          1.0
# 483                  NaN          1.0
#
# [484 rows x 16 columns]

# %%
rewards_df['remainingStockLimit'].value_counts()
# Out:
# remainingStockLimit
# 0.0       31
# 1.0        3
# 25.0       2
# 1000.0     2
# 30.0       1
# 151.0      1
# 204.0      1
# 842.0      1
# 1057.0     1
# 396.0      1
# 1734.0     1
# 1487.0     1
# 247.0      1
# 108.0      1
# 300.0      1
# 43.0       1
# 120.0      1
# 20.0       1
# 192.0      1
# 1400.0     1
# 4500.0     1
# 989.0      1
# 100.0      1
# 70.0       1
# 199.0      1
# 69.0       1
# 934.0      1
# 9.0        1
# 2091.0     1
# 177.0      1
# 39.0       1
# 125.0      1
# 4.0        1
# 46.0       1
# 8.0        1
# 3.0        1
# 13.0       1
# 1562.0     1
# 57.0       1
# 36.0       1
# 733.0      1
# 494.0      1
# 413.0      1
# 691.0      1
# 3000.0     1
# 80.0       1
# Name: count, dtype: int64

# %%
rewards_df.loc[rewards_df["isFeatured"]==True]["main_name"].value_counts()
# Out:
# main_name
# Comber Cat                                                           1
# Crown and War                                                        1
# Falcon's Formula Racing - Relaunch                                   1
# soccerone                                                            1
# THE FAMILY DECK — Indestructible Mafia-Themed Poker Playing Cards    1
#                                                                     ..
# Assault Sicily 43 - Gela Beachhead                                   1
# The Battle of Versailles                                             1
# Bonaparte's Eastern Empire                                           1
# Perseverance: Castaway Chronicles - Episodes 3&4                     1
# MOOGH                                                                1
# Name: count, Length: 237, dtype: int64

# %%
rewards_df.loc[rewards_df["main_name"]=="Goldenstar: The Galactic Tournament"]
# Out:
#                                main_name  projectID  \
# 483  Goldenstar: The Galactic Tournament       1325
#
#                 anchorRelativeUrl  price  isDiscounted  effectivePrice  \
# 483  goldenstar-core-pledge-17700   43.0         False            43.0
#
#      isFeatured  purchasedCopiesCount  \
# 483       False                     0
#
#                                          backgroundUrl  installmentCost  \
# 483  https://imgcdn.gamefound.com/productimage/proj...              NaN
#
#      installmentMinPayment  hasLimitedStock  productCanBePurchased  productID  \
# 483                    NaN            False                  False      17700
#
#      remainingStockLimit  single_item
# 483                  NaN          1.0

# %%
rewards_df.columns
# Out:
# Index(['main_name', 'projectID', 'anchorRelativeUrl', 'price', 'isDiscounted',
#        'effectivePrice', 'isFeatured', 'purchasedCopiesCount', 'backgroundUrl',
#        'installmentCost', 'installmentMinPayment', 'hasLimitedStock',
#        'productCanBePurchased', 'productID', 'remainingStockLimit',
#        'single_item'],
#       dtype='object')

# %%
# price 조인하고 처리해야함 단위 모름

b_list = ['projectID',  'price', 'isDiscounted',
       'effectivePrice', 'installmentMinPayment']

# %%
list(set(rewards_df['projectID']))
# Out:
# [6153,
#  2057,
#  8203,
#  2063,
#  2065,
#  4120,
#  2072,
#  4126,
#  6176,
#  8225,
#  2081,
#  4134,
#  6184,
#  2098,
#  6194,
#  2108,
#  2109,
#  4164,
#  8265,
#  6221,
#  4174,
#  8271,
#  6225,
#  8277,
#  2135,
#  4188,
#  6236,
#  4189,
#  2144,
#  2149,
#  2152,
#  8302,
#  6255,
#  4212,
#  2181,
#  6277,
#  4234,
#  4235,
#  4240,
#  2200,
#  2207,
#  2213,
#  2217,
#  2219,
#  2220,
#  2225,
#  6321,
#  2235,
#  2236,
#  2242,
#  2245,
#  2246,
#  2264,
#  222,
#  2275,
#  8420,
#  6374,
#  2279,
#  6378,
#  6379,
#  6381,
#  4340,
#  2295,
#  4346,
#  2304,
#  2311,
#  2314,
#  2315,
#  4364,
#  4365,
#  4368,
#  6419,
#  8475,
#  6435,
#  4399,
#  4400,
#  2352,
#  6456,
#  2362,
#  4410,
#  4412,
#  4414,
#  2371,
#  8515,
#  8517,
#  2378,
#  8526,
#  6481,
#  4434,
#  2387,
#  2389,
#  2390,
#  6486,
#  4439,
#  4440,
#  2404,
#  2407,
#  2408,
#  4457,
#  4459,
#  6510,
#  6516,
#  4475,
#  6528,
#  2435,
#  2436,
#  6544,
#  4504,
#  2460,
#  4514,
#  6562,
#  6571,
#  2486,
#  2494,
#  4543,
#  6595,
#  6605,
#  2512,
#  2518,
#  4566,
#  2519,
#  2525,
#  6626,
#  6631,
#  2536,
#  4590,
#  4591,
#  4594,
#  2554,
#  6650,
#  4609,
#  6657,
#  4618,
#  4621,
#  2573,
#  2575,
#  6676,
#  4637,
#  4639,
#  4642,
#  4649,
#  4659,
#  4664,
#  4672,
#  2635,
#  2640,
#  2643,
#  2646,
#  6743,
#  4707,
#  6758,
#  2671,
#  6773,
#  4728,
#  2684,
#  4737,
#  2689,
#  4740,
#  2702,
#  4772,
#  2728,
#  4777,
#  2729,
#  4779,
#  2735,
#  4784,
#  4804,
#  2757,
#  2758,
#  2763,
#  2771,
#  6867,
#  2782,
#  2790,
#  2793,
#  4845,
#  4849,
#  2802,
#  2801,
#  2813,
#  2816,
#  6913,
#  769,
#  2823,
#  4874,
#  4879,
#  2832,
#  6941,
#  2847,
#  2850,
#  806,
#  2856,
#  2857,
#  4906,
#  4916,
#  6967,
#  2874,
#  2875,
#  2879,
#  2882,
#  2893,
#  4944,
#  2905,
#  2909,
#  862,
#  4973,
#  2932,
#  887,
#  4983,
#  2935,
#  889,
#  2939,
#  2942,
#  5009,
#  2967,
#  2969,
#  2972,
#  2977,
#  5030,
#  2983,
#  2984,
#  5041,
#  2997,
#  5047,
#  3002,
#  954,
#  3006,
#  3007,
#  5059,
#  5060,
#  5064,
#  3016,
#  975,
#  5077,
#  5082,
#  5084,
#  5090,
#  5097,
#  5104,
#  5108,
#  3066,
#  5125,
#  1032,
#  3082,
#  5133,
#  5142,
#  1060,
#  3112,
#  1066,
#  3119,
#  3124,
#  3125,
#  1078,
#  1081,
#  5180,
#  3135,
#  3136,
#  3144,
#  5197,
#  5198,
#  5199,
#  3151,
#  1103,
#  5202,
#  3154,
#  3161,
#  1114,
#  5211,
#  3166,
#  3175,
#  3176,
#  3183,
#  5234,
#  1143,
#  1145,
#  1148,
#  5258,
#  3211,
#  5261,
#  3215,
#  5275,
#  3232,
#  5281,
#  5284,
#  3236,
#  3244,
#  3248,
#  3252,
#  3261,
#  3273,
#  5325,
#  3278,
#  3282,
#  3285,
#  1248,
#  3298,
#  5349,
#  5357,
#  1263,
#  3313,
#  1268,
#  5386,
#  3339,
#  3340,
#  5395,
#  3347,
#  1301,
#  5401,
#  3360,
#  3365,
#  1318,
#  1320,
#  1325,
#  5423,
#  5429,
#  3383,
#  1342,
#  1348,
#  5446,
#  3402,
#  5452,
#  5454,
#  5463,
#  3425,
#  3444,
#  1398,
#  3453,
#  1405,
#  3457,
#  3459,
#  3478,
#  1430,
#  3484,
#  1438,
#  5536,
#  1442,
#  3493,
#  1449,
#  3499,
#  3503,
#  3506,
#  1460,
#  3515,
#  5563,
#  1476,
#  5584,
#  3539,
#  3546,
#  3547,
#  9693,
#  3554,
#  5609,
#  5625,
#  3582,
#  1539,
#  3588,
#  3592,
#  5640,
#  5644,
#  3612,
#  3617,
#  3618,
#  5669,
#  3623,
#  5676,
#  1599,
#  5715,
#  5719,
#  3678,
#  5730,
#  3685,
#  5737,
#  5738,
#  1643,
#  3692,
#  5739,
#  5740,
#  3695,
#  1661,
#  3711,
#  3723,
#  3724,
#  3726,
#  3731,
#  3734,
#  5787,
#  1691,
#  3745,
#  3748,
#  5802,
#  3755,
#  3766,
#  1720,
#  5817,
#  1721,
#  3771,
#  5820,
#  1725,
#  3775,
#  5838,
#  3797,
#  3803,
#  1755,
#  3810,
#  5862,
#  3815,
#  1767,
#  3818,
#  3828,
#  3830,
#  1782,
#  1790,
#  5887,
#  3844,
#  5894,
#  3847,
#  3848,
#  3849,
#  1799,
#  1804,
#  5900,
#  5906,
#  5918,
#  5920,
#  3877,
#  1837,
#  3890,
#  3895,
#  3897,
#  1851,
#  10044,
#  1856,
#  3906,
#  5956,
#  5958,
#  5969,
#  3922,
#  5971,
#  8024,
#  1888,
#  3937,
#  3941,
#  1893,
#  1897,
#  5995,
#  3949,
#  6007,
#  3960,
#  1919,
#  1926,
#  1927,
#  6026,
#  6033,
#  3988,
#  6039,
#  8091,
#  3997,
#  4003,
#  4007,
#  10156,
#  4013,
#  6064,
#  4018,
#  1977,
#  4034,
#  1986,
#  8130,
#  4037,
#  1987,
#  1991,
#  6088,
#  6087,
#  4042,
#  2002,
#  6099,
#  2005,
#  8150,
#  4065,
#  6117,
#  2023,
#  4078,
#  2032,
#  4088,
#  4093]

# %%
for i in list_df["projectID"]:
    if i not in list(set(rewards_df['projectID'])):
        print(i)
# Out:
# 4358
# 7001
# 5535
# 5043

# %%
drop_ids = [4358, 7001, 5535, 5043]
list_df = list_df[~list_df['projectID'].isin(drop_ids)]

# %%
len(list_df)
# Out:
# 484

# %%
rewards_df[b_list]
# Out:
#      projectID  price  isDiscounted  effectivePrice  installmentMinPayment
# 0         5787  60.00         False           60.00                   75.0
# 1         6481  57.00         False           57.00                  100.0
# 2         8024  69.99          True           56.99                    NaN
# 3         8225  20.00         False           20.00                    NaN
# 4         5995  25.00         False           25.00                    NaN
# ..         ...    ...           ...             ...                    ...
# 479       2109  70.00         False           70.00                    NaN
# 480       2149  19.90          True           13.90                    NaN
# 481       1919  36.00          True           23.00                    NaN
# 482       1143  50.00         False           50.00                    NaN
# 483       1325  43.00         False           43.00                    NaN
#
# [484 rows x 5 columns]

# %% [markdown]
# 조인 후 실행

# %%
final_df = pd.merge(list_df, rewards_df, on='projectID', how='left')
final_df.head()
# Out:
#    projectID  creatorID currencySymbol  campaignGoal  fundsGathered  \
# 0       5787       5252              $       10000.0      393538.44
# 1       6481       6737              $       20000.0      247988.30
# 2       8024       5141              $        7000.0       23091.47
# 3       8225       8739              $         300.0         645.66
# 4       5995       7221              €        1000.0        4042.67
#
#    backersCount         campaignStart               campaignEnd  \
# 0          1567  2025-06-17T14:30:00Z   2025-07-19T00:50:35.25Z
# 1          1075  2026-02-25T16:00:00Z  2026-03-31T15:57:23.953Z
# 2           215  2026-03-01T05:00:00Z      2026-04-01T05:00:00Z
# 3            12  2026-02-02T13:00:00Z      2026-03-02T13:00:00Z
# 4            89  2026-01-16T12:00:00Z      2026-02-28T12:00:00Z
#
#                 phaseLabel  enableBoardGameProperties  minPlayers  maxPlayers  \
# 0  Pledge manager - Closed                      False         NaN         NaN
# 1  Pledge manager - Closed                       True         1.0         4.0
# 2  Pledge manager - Closed                       True         1.0         2.0
# 3  Pledge manager - Closed                       True         2.0         5.0
# 4  Pledge manager - Closed                       True         2.0         6.0
#
#    minAge  playTime  playTimeUnit  fundedInSeconds  \
# 0     NaN       NaN             0              628
# 1    13.0      90.0             0             2716
# 2    12.0       8.0             1            56442
# 3     8.0      15.0             0          2409627
# 4     8.0      20.0             0            14439
#
#   pledgeManagerSoftCloseDeadline  \
# 0           2026-06-02T15:00:00Z
# 1           2026-06-01T14:00:00Z
# 2                            NaN
# 3                            NaN
# 4           2026-06-11T13:00:00Z
#
#                                          projectTags  \
# 0  Exploration, Horror, Modern, Science Fiction, ...
# 1  History, Strategy, Wargame, Action, Collectibl...
# 2                         History, Strategy, Wargame
# 3            Card Game, Strategy, Party game, Family
# 4  Strategy, Resource management, Family, Worker ...
#
#                                     main_name  \
# 0  We Played God - A Survival Miniatures Game
# 1                                   CARNIVORE
# 2                              1809: Talavera
# 3                                  Comber Cat
# 4                  Jano - A Pawsome Adventure
#
#                   anchorRelativeUrl  price  isDiscounted  effectivePrice  \
# 0     core-rules-physical-pdf-80323  60.00         False           60.00
# 1       megapredator-digital-102621  57.00         False           57.00
# 2  backers-copy-1809-talavera-99555  69.99          True           56.99
# 3                  cat-lovers-99754  20.00         False           20.00
# 4             jano-board-game-92756  25.00         False           25.00
#
#    isFeatured  purchasedCopiesCount  \
# 0       False                     0
# 1       False                     0
# 2       False                     0
# 3        True                     0
# 4        True                     0
#
#                                        backgroundUrl  installmentCost  \
# 0  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 1  https://imgcdn.gamefound.com/productimage/proj...             28.5
# 2  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 3  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 4  https://imgcdn.gamefound.com/productimage/proj...              NaN
#
#    installmentMinPayment  hasLimitedStock  productCanBePurchased  productID  \
# 0                   75.0            False                  False      80323
# 1                  100.0            False                  False     102621
# 2                    NaN            False                  False      99555
# 3                    NaN            False                  False      99754
# 4                    NaN            False                  False      92756
#
#    remainingStockLimit  single_item
# 0                  NaN          1.0
# 1                  NaN          1.0
# 2                  NaN          1.0
# 3                  NaN          1.0
# 4                  NaN          1.0

# %%
final_df['campaignStart'] = pd.to_datetime(final_df['campaignStart'])
final_df['campaignEnd'] = pd.to_datetime(final_df['campaignEnd'], format='ISO8601')


# creatorID -> 그 당시 몇개 만들었는지
final_df = final_df.sort_values(by='campaignStart')
final_df['previous_campaigns_count'] = final_df.groupby('creatorID').cumcount()
final_df = final_df.sort_index()

# 프로젝트 진행 기간 계산
final_df['duration_days'] = (final_df['campaignEnd'] - final_df['campaignStart']).dt.days

# 댓글 수집 기준일 계산 (시작일로부터 1주일, 2주일 뒤) 댓글 조인 후 날짜 잘라도?
#final_df['comment_target_1w'] = final_df['campaignStart'] + pd.Timedelta(days=7)

# playTime 단위 통일 (playTimeUnit이 1이면 시간 단위 -> 분으로 변환)
final_df.loc[final_df['playTimeUnit'] == 1, 'playTime'] = final_df['playTime'] * 60

# pledgeManagerSoftCloseDeadline 존재 여부 (방치 여부/관리 척도)
final_df['softclose'] = final_df['pledgeManagerSoftCloseDeadline'].notna().astype(int)

# projectTags 원핫인코딩
#tags_encoded = final_df['projectTags'].fillna('').str.get_dummies(sep=', ')
#final_df = pd.concat([final_df, tags_encoded], axis=1)

# %%
from datetime import date, timedelta
import requests
import numpy as np
import pandas as pd
import time

# ==========================================
# 1. 기준 날짜 세팅
# ==========================================
end_date = date.today()
start_date_1m = end_date - timedelta(days=30)
start_date_6m = end_date - timedelta(days=180)

# ==========================================
# 2. 지워진 환율 계산 함수 복구
# ==========================================
def get_avg_rates_to_usd(base_currency, start_1m, start_6m, end_dt):
    """
    한 번의 API 호출로 1개월, 6개월 평균 환율을 동시에 계산하여 반환
    """
    if base_currency == "USD" or pd.isna(base_currency):
        return 1.0, 1.0

    url = (
        f"https://api.frankfurter.app/"
        f"{start_6m}..{end_dt}"
        f"?base={base_currency}&symbols=USD"
    )

    res = requests.get(url)
    if res.status_code != 200:
        return np.nan, np.nan # 에러 발생 시 결측치 반환
        
    data = res.json()
    rates_1m = []
    rates_6m = []
    
    start_1m_str = start_1m.isoformat()

    for day, rate_info in data["rates"].items():
        if "USD" in rate_info:
            val = rate_info["USD"]
            rates_6m.append(val)
            if day >= start_1m_str:
                rates_1m.append(val)

    avg_1m = sum(rates_1m) / len(rates_1m) if rates_1m else np.nan
    avg_6m = sum(rates_6m) / len(rates_6m) if rates_6m else np.nan

    return avg_1m, avg_6m

# %%
# ==========================================
# 1. 만들어두신 통화 변환 코드 (그대로 사용!)
# ==========================================
symbol_to_code = {
    "$": "USD",
    "€": "EUR",
    "£": "GBP",
    "A$": "AUD",
    "C$": "CAD",
    "S$": "SGD",
    "zł": "PLN",
    "kr": "SEK",
    "kr.": "SEK",
    "Fr.": "CHF",
    "HK$": "HKD",
    "NZ$": "NZD",
    "Mex$": "MXN",
}

# 임시 정리용 컬럼 생성
final_df["_currencySymbol_clean"] = final_df["currencySymbol"].astype("string").str.strip()

# 최종으로 남길 currencyCode 컬럼 추가
final_df["currencyCode"] = final_df["_currencySymbol_clean"].map(symbol_to_code)

# 매핑 안 된 통화기호 확인
unmapped = final_df[final_df["currencyCode"].isna()]["currencySymbol"].drop_duplicates()
print("매핑 안 된 통화기호:")
print(unmapped)

# ==========================================
# 2. 환율 API 호출 및 데이터프레임 생성
# ==========================================
# NaN을 제외한 고유한 통화 코드만 리스트로 추출
currency_codes = final_df["currencyCode"].dropna().unique().tolist()
rates_data = []

print("\n환율 정보를 가져오는 중입니다...")
for code in currency_codes:
    # get_avg_rates_to_usd 함수와 날짜 변수들은 위 셀에서 실행해두셨다고 가정합니다.
    rate_1m, rate_6m = get_avg_rates_to_usd(code, start_date_1m, start_date_6m, end_date)
    
    rates_data.append({
        "currencyCode": code,
        "avg_rate_to_usd_1m": rate_1m,
        "avg_rate_to_usd_6m": rate_6m
    })
    
    time.sleep(1) # 차단 방지

rate_df = pd.DataFrame(rates_data)

# ==========================================
# 3. 원본 데이터(final_df)에 환율 데이터 병합(Merge)
# ==========================================
final_df = pd.merge(final_df, rate_df, on="currencyCode", how="left")

# ==========================================
# 4. 특수기호 제거 및 USD 환산 계산
# ==========================================
# 숫자 변환 (이전에 만들어둔 정규표현식 사용)
final_df["campaignGoal"] = pd.to_numeric(final_df["campaignGoal"].astype(str).str.replace(r'[^\d\.]', '', regex=True), errors="coerce")
final_df["fundsGathered"] = pd.to_numeric(final_df["fundsGathered"].astype(str).str.replace(r'[^\d\.]', '', regex=True), errors="coerce")
final_df["price"] = pd.to_numeric(final_df["price"].astype(str).str.replace(r'[^\d\.]', '', regex=True), errors="coerce")
final_df["effectivePrice"] = pd.to_numeric(final_df["effectivePrice"].astype(str).str.replace(r'[^\d\.]', '', regex=True), errors="coerce")


# 1달 기준 환산
final_df["campaignGoal_usd_1m"] = final_df["campaignGoal"] * final_df["avg_rate_to_usd_1m"]
final_df["fundsGathered_usd_1m"] = final_df["fundsGathered"] * final_df["avg_rate_to_usd_1m"]
final_df["price_usd_1m"] = final_df["price"] * final_df["avg_rate_to_usd_1m"]
final_df["effectivePrice"] = final_df["effectivePrice"] * final_df["avg_rate_to_usd_1m"]
# 6달 기준 환산
final_df["campaignGoal_usd_6m"] = final_df["campaignGoal"] * final_df["avg_rate_to_usd_6m"]
final_df["fundsGathered_usd_6m"] = final_df["fundsGathered"] * final_df["avg_rate_to_usd_6m"]
final_df["price_usd_6m"] = final_df["price"] * final_df["avg_rate_to_usd_6m"]
final_df["effectivePrice"] = final_df["effectivePrice"] * final_df["avg_rate_to_usd_6m"]
# Out:
# 매핑 안 된 통화기호:
# Series([], Name: currencySymbol, dtype: object)
#
# 환율 정보를 가져오는 중입니다...

# %%
final_df.head()
# Out:
#    projectID  creatorID currencySymbol  campaignGoal  fundsGathered  \
# 0       5787       5252              $       10000.0      393538.44
# 1       6481       6737              $       20000.0      247988.30
# 2       8024       5141              $        7000.0       23091.47
# 3       8225       8739              $         300.0         645.66
# 4       5995       7221              €        1000.0        4042.67
#
#    backersCount             campaignStart                      campaignEnd  \
# 0          1567 2025-06-17 14:30:00+00:00 2025-07-19 00:50:35.250000+00:00
# 1          1075 2026-02-25 16:00:00+00:00 2026-03-31 15:57:23.953000+00:00
# 2           215 2026-03-01 05:00:00+00:00        2026-04-01 05:00:00+00:00
# 3            12 2026-02-02 13:00:00+00:00        2026-03-02 13:00:00+00:00
# 4            89 2026-01-16 12:00:00+00:00        2026-02-28 12:00:00+00:00
#
#                 phaseLabel  enableBoardGameProperties  minPlayers  maxPlayers  \
# 0  Pledge manager - Closed                      False         NaN         NaN
# 1  Pledge manager - Closed                       True         1.0         4.0
# 2  Pledge manager - Closed                       True         1.0         2.0
# 3  Pledge manager - Closed                       True         2.0         5.0
# 4  Pledge manager - Closed                       True         2.0         6.0
#
#    minAge  playTime  playTimeUnit  fundedInSeconds  \
# 0     NaN       NaN             0              628
# 1    13.0      90.0             0             2716
# 2    12.0     480.0             1            56442
# 3     8.0      15.0             0          2409627
# 4     8.0      20.0             0            14439
#
#   pledgeManagerSoftCloseDeadline  \
# 0           2026-06-02T15:00:00Z
# 1           2026-06-01T14:00:00Z
# 2                            NaN
# 3                            NaN
# 4           2026-06-11T13:00:00Z
#
#                                          projectTags  \
# 0  Exploration, Horror, Modern, Science Fiction, ...
# 1  History, Strategy, Wargame, Action, Collectibl...
# 2                         History, Strategy, Wargame
# 3            Card Game, Strategy, Party game, Family
# 4  Strategy, Resource management, Family, Worker ...
#
#                                     main_name  \
# 0  We Played God - A Survival Miniatures Game
# 1                                   CARNIVORE
# 2                              1809: Talavera
# 3                                  Comber Cat
# 4                  Jano - A Pawsome Adventure
#
#                   anchorRelativeUrl  price  isDiscounted  effectivePrice  \
# 0     core-rules-physical-pdf-80323  60.00         False        60.00000
# 1       megapredator-digital-102621  57.00         False        57.00000
# 2  backers-copy-1809-talavera-99555  69.99          True        56.99000
# 3                  cat-lovers-99754  20.00         False        20.00000
# 4             jano-board-game-92756  25.00         False        34.10092
#
#    isFeatured  purchasedCopiesCount  \
# 0       False                     0
# 1       False                     0
# 2       False                     0
# 3        True                     0
# 4        True                     0
#
#                                        backgroundUrl  installmentCost  \
# 0  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 1  https://imgcdn.gamefound.com/productimage/proj...             28.5
# 2  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 3  https://imgcdn.gamefound.com/productimage/proj...              NaN
# 4  https://imgcdn.gamefound.com/productimage/proj...              NaN
#
#    installmentMinPayment  hasLimitedStock  productCanBePurchased  productID  \
# 0                   75.0            False                  False      80323
# 1                  100.0            False                  False     102621
# 2                    NaN            False                  False      99555
# 3                    NaN            False                  False      99754
# 4                    NaN            False                  False      92756
#
#    remainingStockLimit  single_item  previous_campaigns_count  duration_days  \
# 0                  NaN          1.0                         0             31
# 1                  NaN          1.0                         0             33
# 2                  NaN          1.0                         1             31
# 3                  NaN          1.0                         0             28
# 4                  NaN          1.0                         0             43
#
#    softclose _currencySymbol_clean currencyCode  avg_rate_to_usd_1m  \
# 0          1                     $          USD            1.000000
# 1          1                     $          USD            1.000000
# 2          0                     $          USD            1.000000
# 3          0                     $          USD            1.000000
# 4          1                     €          EUR            1.165932
#
#    avg_rate_to_usd_6m  campaignGoal_usd_1m  fundsGathered_usd_1m  \
# 0            1.000000         10000.000000         393538.440000
# 1            1.000000         20000.000000         247988.300000
# 2            1.000000          7000.000000          23091.470000
# 3            1.000000           300.000000            645.660000
# 4            1.169911          1165.931818           4713.477583
#
#    price_usd_1m  campaignGoal_usd_6m  fundsGathered_usd_6m  price_usd_6m
# 0     60.000000          10000.00000         393538.440000     60.000000
# 1     57.000000          20000.00000         247988.300000     57.000000
# 2     69.990000           7000.00000          23091.470000     69.990000
# 3     20.000000            300.00000            645.660000     20.000000
# 4     29.148295           1169.91129           4729.565276     29.247782

# %%
final_df = final_df.drop(columns=['creatorID','playTimeUnit','campaignGoal','fundsGathered','campaignStart','campaignEnd',
                                  'playTimeUnit', 'pledgeManagerSoftCloseDeadline','main_name','anchorRelativeUrl','price','effectivePrice',
                                  'purchasedCopiesCount','backgroundUrl','installmentCost','productID','single_item','remainingStockLimit','_currencySymbol_clean',
                                  'currencyCode','avg_rate_to_usd_1m','avg_rate_to_usd_6m'])

# %%
final_df
# Out:
#      projectID currencySymbol  backersCount                   phaseLabel  \
# 0         5787              $          1567      Pledge manager - Closed
# 1         6481              $          1075      Pledge manager - Closed
# 2         8024              $           215      Pledge manager - Closed
# 3         8225              $            12      Pledge manager - Closed
# 4         5995              €            89      Pledge manager - Closed
# ..         ...            ...           ...                          ...
# 479       2109              €           113  Crowdfunding - Unsuccessful
# 480       2149              €             2  Crowdfunding - Unsuccessful
# 481       1919              €           143  Crowdfunding - Unsuccessful
# 482       1143              €           158  Crowdfunding - Unsuccessful
# 483       1325              €           148  Crowdfunding - Unsuccessful
#
#      enableBoardGameProperties  minPlayers  maxPlayers  minAge  playTime  \
# 0                        False         NaN         NaN     NaN       NaN
# 1                         True         1.0         4.0    13.0      90.0
# 2                         True         1.0         2.0    12.0     480.0
# 3                         True         2.0         5.0     8.0      15.0
# 4                         True         2.0         6.0     8.0      20.0
# ..                         ...         ...         ...     ...       ...
# 479                       True         2.0         4.0    14.0     180.0
# 480                       True         2.0         4.0     5.0      25.0
# 481                       True         1.0         4.0    14.0      30.0
# 482                       True         2.0         4.0    12.0     120.0
# 483                       True         2.0         4.0    14.0      60.0
#
#      fundedInSeconds                                        projectTags  \
# 0                628  Exploration, Horror, Modern, Science Fiction, ...
# 1               2716  History, Strategy, Wargame, Action, Collectibl...
# 2              56442                         History, Strategy, Wargame
# 3            2409627            Card Game, Strategy, Party game, Family
# 4              14439  Strategy, Resource management, Family, Worker ...
# ..               ...                                                ...
# 479                0  Strategy, Wargame, Dice Game, Area Control, Co...
# 480                0                           Fantasy, Strategy, Humor
# 481                0      Dice Game, Multiplayer, Competitive, Campaign
# 482                0         Fantasy, Strategy, Terrain Building, Humor
# 483                0       Science Fiction, Area Control, Deck Building
#
#      isDiscounted  isFeatured  installmentMinPayment  hasLimitedStock  \
# 0           False       False                   75.0            False
# 1           False       False                  100.0            False
# 2            True       False                    NaN            False
# 3           False        True                    NaN            False
# 4           False        True                    NaN            False
# ..            ...         ...                    ...              ...
# 479         False        True                    NaN            False
# 480          True       False                    NaN            False
# 481          True        True                    NaN            False
# 482         False       False                    NaN            False
# 483         False       False                    NaN            False
#
#      productCanBePurchased  previous_campaigns_count  duration_days  \
# 0                    False                         0             31
# 1                    False                         0             33
# 2                    False                         1             31
# 3                    False                         0             28
# 4                    False                         0             43
# ..                     ...                       ...            ...
# 479                  False                         0             21
# 480                  False                         0             30
# 481                  False                         0             16
# 482                  False                         0             33
# 483                  False                         0             24
#
#      softclose  campaignGoal_usd_1m  fundsGathered_usd_1m  price_usd_1m  \
# 0            1         10000.000000         393538.440000     60.000000
# 1            1         20000.000000         247988.300000     57.000000
# 2            0          7000.000000          23091.470000     69.990000
# 3            0           300.000000            645.660000     20.000000
# 4            1          1165.931818           4713.477583     29.148295
# ..         ...                  ...                   ...           ...
# 479          0         23318.636364           9328.620477     81.615227
# 480          0         11426.131818             81.615227     23.202043
# 481          0         11659.318182           7327.881477     41.973545
# 482          0         23318.636364          15647.539537     58.296591
# 483          0         34977.954545          12696.997500     50.135068
#
#      campaignGoal_usd_6m  fundsGathered_usd_6m  price_usd_6m
# 0           10000.000000         393538.440000     60.000000
# 1           20000.000000         247988.300000     57.000000
# 2            7000.000000          23091.470000     69.990000
# 3             300.000000            645.660000     20.000000
# 4            1169.911290           4729.565276     29.247782
# ..                   ...                   ...           ...
# 479         23398.225806           9360.460234     81.893790
# 480         11465.130645             81.893790     23.281235
# 481         11699.112903           7352.892460     42.116806
# 482         23398.225806          15700.946560     58.495565
# 483         35097.338710          12740.333952     50.306185
#
# [484 rows x 25 columns]

# %%
final_df.to_csv("../../02_Data/processed/list+rewards_join.csv", index=False, encoding="utf-8-sig")

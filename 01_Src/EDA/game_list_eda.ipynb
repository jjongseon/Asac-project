# %%
import pandas as pd

df = pd.read_csv("../../02_Data/raw/gamefound_list.csv")

# %%
df.columns
# Out:
# Index(['name', 'projectID', 'creator', 'creatorID', 'homeUrl',
#        'currencySymbol', 'campaignGoal', 'fundsGathered', 'backersCount',
#        'campaignStart', 'campaignEnd', 'description', 'project_url',
#        'phaseLabel', 'enableBoardGameProperties', 'minPlayers', 'maxPlayers',
#        'minAge', 'playTime', 'playTimeDescription', 'playTimeUnit',
#        'pledgeManagerAvailability', 'fundedInSeconds', 'imageUrl',
#        'pledgeManagerSoftCloseDeadline', 'projectTags',
#        'enableShippingOnlyMode', 'originalType'],
#       dtype='object')

# %%
a_list = ['name', 'projectID', 'creator', 'creatorID', 'homeUrl',
       'currencySymbol', 'campaignGoal', 'fundsGathered', 'backersCount',
       'campaignStart', 'campaignEnd',
       'phaseLabel', 'enableBoardGameProperties', 'minPlayers', 'maxPlayers',
       'minAge', 'playTime', 'playTimeUnit',
       'fundedInSeconds', 'imageUrl',
       'pledgeManagerSoftCloseDeadline', 'projectTags',
       'originalType']

# %%
pd.set_option('display.max_columns', None)
df = df[a_list]

# %%
df.loc[df['originalType']==0]
# Out:
#                                                name  projectID  \
# 440                                Escape From mars      10054
# 442                                  Beat Box Party      10072
# 446                            Travel Bug Card Game      11304
# 448   The Malice of Light Adventures Pledge Manager      10154
# 455                         The Cats of New Orleans       9843
# ...                                             ...        ...
# 2281                             GKR: Heavy Hitters         13
# 2282                               Endure The Stars         12
# 2283                        Star Scrappers: Cave-In          9
# 2284                                     Board&Dice          8
# 2285                       BATTALIA: The Stormgates          3
#
#                       creator  creatorID  \
# 440       Dark Frontier Games       4262
# 442       Boiling Point Games       8720
# 446              DominoTracks       8807
# 448         Twin Tale Studios       7366
# 455              Raybox Games        278
# ...                       ...        ...
# 2281            Weta Workshop         11
# 2282           Grimlord Games         10
# 2283              Hexy Studio          7
# 2284               Board&Dice          6
# 2285  Fantasmagoria Games LLC          5
#
#                                                 homeUrl currencySymbol  \
# 440                  https://gamefound.com/creators/dfg              £
# 442   https://gamefound.com/creators/boiling-point-g...              $
# 446         https://gamefound.com/creators/dominotracks              $
# 448    https://gamefound.com/creators/twin-tale-studios              $
# 455          https://gamefound.com/creators/rayboxgames             C$
# ...                                                 ...            ...
# 2281       https://gamefound.com/creators/weta-workshop              $
# 2282      https://gamefound.com/creators/grimlord-games              £
# 2283         https://gamefound.com/creators/hexy-studio              $
# 2284      https://gamefound.com/creators/board-and-dice              $
# 2285  https://gamefound.com/creators/fantasmagoria-g...              $
#
#       campaignGoal  fundsGathered  backersCount campaignStart campaignEnd  \
# 440            NaN       41989.04           705           NaN         NaN
# 442            NaN        8290.00            65           NaN         NaN
# 446            NaN        4584.00            21           NaN         NaN
# 448            NaN       78301.58           727           NaN         NaN
# 455            NaN      201031.73          1069           NaN         NaN
# ...            ...            ...           ...           ...         ...
# 2281           NaN           0.00             0           NaN         NaN
# 2282           NaN           0.00             0           NaN         NaN
# 2283           NaN           0.00             0           NaN         NaN
# 2284           NaN           0.00             0           NaN         NaN
# 2285           NaN           0.00             0           NaN         NaN
#
#                          phaseLabel  enableBoardGameProperties  minPlayers  \
# 440      Late Pledge - Open for all                       True         1.0
# 442   Pledge manager - Open for all                       True         3.0
# 446      Late Pledge - Open for all                       True         2.0
# 448   Pledge manager - Open for all                       True         1.0
# 455   Pledge manager - Open for all                       True         1.0
# ...                             ...                        ...         ...
# 2281        Pledge manager - Closed                      False         NaN
# 2282        Pledge manager - Closed                      False         NaN
# 2283        Pledge manager - Closed                      False         NaN
# 2284        Pledge manager - Closed                      False         NaN
# 2285        Pledge manager - Closed                      False         NaN
#
#       maxPlayers  minAge  playTime  playTimeUnit  fundedInSeconds  \
# 440          4.0    14.0      80.0             0                0
# 442         10.0    14.0      15.0             0                0
# 446          4.0     8.0      15.0             0                0
# 448          4.0    14.0      90.0             0                0
# 455          4.0    14.0      30.0             0                0
# ...          ...     ...       ...           ...              ...
# 2281         NaN     NaN       NaN             0                0
# 2282         NaN     NaN       NaN             0                0
# 2283         NaN     NaN       NaN             0                0
# 2284         NaN     NaN       NaN             0                0
# 2285         NaN     NaN       NaN             0                0
#
#                                                imageUrl  \
# 440   https://imgcdn.gamefound.com/projectimage/proj...
# 442   https://imgcdn.gamefound.com/projectimage/proj...
# 446   https://imgcdn.gamefound.com/projectimage/proj...
# 448   https://imgcdn.gamefound.com/projectimage/proj...
# 455   https://imgcdn.gamefound.com/projectimage/proj...
# ...                                                 ...
# 2281  https://imgcdn.gamefound.com/projectimage/proj...
# 2282  https://imgcdn.gamefound.com/projectimage/proj...
# 2283  https://imgcdn.gamefound.com/projectimage/proj...
# 2284  https://imgcdn.gamefound.com/projectimage/proj...
# 2285  https://imgcdn.gamefound.com/projectimage/proj...
#
#      pledgeManagerSoftCloseDeadline  \
# 440                             NaN
# 442            2026-08-31T17:00:00Z
# 446                             NaN
# 448                             NaN
# 455                             NaN
# ...                             ...
# 2281                            NaN
# 2282                            NaN
# 2283                            NaN
# 2284                            NaN
# 2285                            NaN
#
#                                             projectTags  originalType
# 440   Horror, Science Fiction, Survival, Dice Game, ...             0
# 442                                          Party game             0
# 446                        Card Game, Adventure, Family             0
# 448   Card Game, Fantasy, Dice Game, Strategy, Coope...             0
# 455       Fantasy, Mythology, Digital, Adventure, Paint             0
# ...                                                 ...           ...
# 2281  Wargame, Science Fiction, Dice Game, Area Control             0
# 2282                          Science Fiction, Survival             0
# 2283          Card Game, Science Fiction, Deck Building             0
# 2284  Exploration, Fantasy, Card Game, History, Stra...             0
# 2285  Card Game, Fantasy, Strategy, Terrain Building...             0
#
# [1115 rows x 23 columns]

# %%
df.loc[df['originalType']==1]
# Out:
#                                      name  projectID             creator  \
# 0                              Bloodstone       8454    Druid City Games
# 2                                  A Life       9816       Skellig Games
# 3           Growing Season Deluxe Edition       8617           Undigital
# 4               Stonesaga Second Printing       9678    Open Owl Studios
# 5                          Beast: Ashfall       8330      Studio Midhall
# ...                                   ...        ...                 ...
# 2585    Spring and Autumn: Story of China       1446        Mr. B. Games
# 2586       Crossroads Inn: The Board Game       1143            Klabater
# 2587                            PACHAMAMA       1170             SitDown
# 2588         Taverns & Dragons (Canceled)       1314  Lord Raccoon Games
# 2589  Goldenstar: The Galactic Tournament       1325               Gindi
#
#       creatorID                                          homeUrl  \
# 0          8843  https://gamefound.com/creators/druid-city-games
# 2          2434     https://gamefound.com/creators/skellig-games
# 3          5415         https://gamefound.com/creators/undigital
# 4           474        https://gamefound.com/creators/oomm-games
# 5          2936    https://gamefound.com/creators/studio-midhall
# ...         ...                                              ...
# 2585       1954        https://gamefound.com/creators/mr-b-games
# 2586       1510          https://gamefound.com/creators/klabater
# 2587       1514           https://gamefound.com/creators/sitdown
# 2588        356     https://gamefound.com/creators/thelastbottle
# 2589         64             https://gamefound.com/creators/gindi
#
#      currencySymbol  campaignGoal  fundsGathered  backersCount  \
# 0                 $       50000.0       95253.93           479
# 2                 €       10000.0       22796.57           203
# 3                 €        8000.0       15291.46           361
# 4                 $       25000.0      154784.30          1791
# 5                 €       50000.0      490554.96          3420
# ...             ...           ...            ...           ...
# 2585              $       30000.0       38009.00           219
# 2586              €       20000.0       13420.63           158
# 2587              €       25000.0       16048.00           318
# 2588              €       20000.0       20954.00           470
# 2589              €       30000.0       10890.00           148
#
#              campaignStart           campaignEnd                   phaseLabel  \
# 0     2026-06-02T13:00:00Z  2026-06-19T22:00:00Z                 Crowdfunding
# 2     2026-06-02T15:00:00Z  2026-06-25T18:00:00Z                 Crowdfunding
# 3     2026-06-02T16:00:00Z  2026-06-22T22:00:00Z                 Crowdfunding
# 4     2026-05-26T15:00:00Z  2026-06-20T00:00:00Z                 Crowdfunding
# 5     2026-05-05T15:00:00Z  2026-06-03T22:00:00Z                 Crowdfunding
# ...                    ...                   ...                          ...
# 2585  2021-12-01T15:00:00Z  2022-01-04T22:00:00Z      Crowdfunding - Canceled
# 2586  2021-10-28T14:00:00Z  2021-11-30T15:00:00Z  Crowdfunding - Unsuccessful
# 2587  2021-10-19T17:00:00Z  2021-11-09T18:00:00Z      Crowdfunding - Canceled
# 2588  2021-10-12T13:00:00Z  2021-11-03T22:00:00Z      Crowdfunding - Canceled
# 2589  2021-10-05T16:00:00Z  2021-10-29T16:00:00Z  Crowdfunding - Unsuccessful
#
#       enableBoardGameProperties  minPlayers  maxPlayers  minAge  playTime  \
# 0                          True         1.0         5.0    14.0      60.0
# 2                          True         1.0         4.0     8.0      60.0
# 3                          True         1.0         4.0     8.0      30.0
# 4                          True         1.0         4.0     NaN      90.0
# 5                          True         2.0         5.0    14.0     120.0
# ...                         ...         ...         ...     ...       ...
# 2585                       True         1.0         5.0    13.0     120.0
# 2586                       True         2.0         4.0    12.0     120.0
# 2587                       True         1.0         4.0    14.0      60.0
# 2588                       True         2.0         5.0    10.0      60.0
# 2589                       True         2.0         4.0    14.0      60.0
#
#       playTimeUnit  fundedInSeconds  \
# 0                0             7770
# 2                0             3756
# 3                0             4725
# 4                0             1764
# 5                0             3645
# ...            ...              ...
# 2585             0           182152
# 2586             0                0
# 2587             0                0
# 2588             0           433495
# 2589             0                0
#
#                                                imageUrl  \
# 0     https://imgcdn.gamefound.com/projectimage/proj...
# 2     https://imgcdn.gamefound.com/projectimage/proj...
# 3     https://imgcdn.gamefound.com/projectimage/proj...
# 4     https://imgcdn.gamefound.com/projectimage/proj...
# 5     https://imgcdn.gamefound.com/projectimage/proj...
# ...                                                 ...
# 2585  https://imgcdn.gamefound.com/projectimage/proj...
# 2586  https://imgcdn.gamefound.com/projectimage/proj...
# 2587  https://imgcdn.gamefound.com/projectimage/proj...
# 2588  https://imgcdn.gamefound.com/projectimage/proj...
# 2589  https://imgcdn.gamefound.com/projectimage/proj...
#
#      pledgeManagerSoftCloseDeadline  \
# 0                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# ...                             ...
# 2585                            NaN
# 2586                            NaN
# 2587                            NaN
# 2588                            NaN
# 2589                            NaN
#
#                                             projectTags  originalType
# 0     Fantasy, Multiplayer, Competitive, Dice Game, ...             1
# 2     Set Collection, Competitive, Family, Narrative...             1
# 3     Card Game, Strategy, Video Game Theme, Multipl...             1
# 4     Fantasy, Mythology, Cooperative, Campaign, Civ...             1
# 5     Fantasy, Strategy, Multiplayer, Competitive, A...             1
# ...                                                 ...           ...
# 2585       Exploration, History, Strategy, Area Control             1
# 2586         Fantasy, Strategy, Terrain Building, Humor             1
# 2587  Exploration, Logical, Deduction, Terrain Building             1
# 2588  Exploration, Card Game, Fantasy, Dice Game, St...             1
# 2589       Science Fiction, Area Control, Deck Building             1
#
# [1402 rows x 23 columns]

# %%
df.loc[df['originalType']==1]['phaseLabel'].value_counts()
# Out:
# Upcoming                         389
# Pledge manager - Closed          322
# Pledge manager - Limited         148
# Crowdfunding - Canceled          136
# Crowdfunding - Unsuccessful      124
# Pledge manager - Open for all    112
# Late Pledge - Open for all        89
# Crowdfunding - Funded             42
# Crowdfunding                      39
# Late Pledge - Ended                1
# Name: phaseLabel, dtype: int64

# %%
target_list = ["Pledge manager - Closed","Crowdfunding - Unsuccessful","Crowdfunding - Funded"]

# %%
df = df.loc[(df['originalType']==1)&(df['phaseLabel'].isin(target_list))].reset_index(drop=True)

# %%
df.to_csv("../../02_data/processed/final_gamefound_list.csv", index=False, encoding="utf-8-sig")

# %%
df
# Out:
#                                            name  projectID  \
# 0    We Played God - A Survival Miniatures Game       5787
# 1                                     CARNIVORE       6481
# 2                                1809: Talavera       8024
# 3                                    Comber Cat       8225
# 4                    Jano - A Pawsome Adventure       5995
# ..                                          ...        ...
# 483                                    Tectonia       2109
# 484                              Invasion Cards       2149
# 485                                       MOOGH       1919
# 486              Crossroads Inn: The Board Game       1143
# 487         Goldenstar: The Galactic Tournament       1325
#
#                 creator  creatorID  \
# 0    Black Site Studios       5252
# 1            Buer Games       6737
# 2     Tactical Workshop       5141
# 3      Gamedolf Limited       8739
# 4                aszaki       7221
# ..                  ...        ...
# 483          Hagen Behr       2703
# 484       Lawrence Lyle       2742
# 485    Nuts! Publishing       2363
# 486            Klabater       1510
# 487               Gindi         64
#
#                                                homeUrl currencySymbol  \
# 0    https://gamefound.com/creators/black-site-studios              $
# 1            https://gamefound.com/creators/buer-games              $
# 2     https://gamefound.com/creators/tactical-workshop              $
# 3       https://gamefound.com/creators/gamedolflimited              $
# 4                https://gamefound.com/creators/aszaki              €
# ..                                                 ...            ...
# 483          https://gamefound.com/creators/hagen-behr              €
# 484       https://gamefound.com/creators/lawrence-lyle              €
# 485     https://gamefound.com/creators/nuts-publishing              €
# 486            https://gamefound.com/creators/klabater              €
# 487               https://gamefound.com/creators/gindi              €
#
#      campaignGoal  fundsGathered  backersCount         campaignStart  \
# 0         10000.0      393538.44          1567  2025-06-17T14:30:00Z
# 1         20000.0      247988.30          1075  2026-02-25T16:00:00Z
# 2          7000.0       23091.47           215  2026-03-01T05:00:00Z
# 3           300.0         645.66            12  2026-02-02T13:00:00Z
# 4          1000.0        4042.67            89  2026-01-16T12:00:00Z
# ..            ...            ...           ...                   ...
# 483       20000.0        8001.00           113  2022-07-05T18:00:00Z
# 484        9800.0          70.00             2  2022-07-04T10:00:00Z
# 485       10000.0        6285.00           143  2022-04-26T16:00:00Z
# 486       20000.0       13420.63           158  2021-10-28T14:00:00Z
# 487       30000.0       10890.00           148  2021-10-05T16:00:00Z
#
#                   campaignEnd                   phaseLabel  \
# 0     2025-07-19T00:50:35.25Z      Pledge manager - Closed
# 1    2026-03-31T15:57:23.953Z      Pledge manager - Closed
# 2        2026-04-01T05:00:00Z      Pledge manager - Closed
# 3        2026-03-02T13:00:00Z      Pledge manager - Closed
# 4        2026-02-28T12:00:00Z      Pledge manager - Closed
# ..                        ...                          ...
# 483      2022-07-26T18:00:00Z  Crowdfunding - Unsuccessful
# 484      2022-08-03T21:00:00Z  Crowdfunding - Unsuccessful
# 485      2022-05-12T16:00:00Z  Crowdfunding - Unsuccessful
# 486      2021-11-30T15:00:00Z  Crowdfunding - Unsuccessful
# 487      2021-10-29T16:00:00Z  Crowdfunding - Unsuccessful
#
#      enableBoardGameProperties  minPlayers  maxPlayers  minAge  playTime  \
# 0                        False         NaN         NaN     NaN       NaN
# 1                         True         1.0         4.0    13.0      90.0
# 2                         True         1.0         2.0    12.0       8.0
# 3                         True         2.0         5.0     8.0      15.0
# 4                         True         2.0         6.0     8.0      20.0
# ..                         ...         ...         ...     ...       ...
# 483                       True         2.0         4.0    14.0     180.0
# 484                       True         2.0         4.0     5.0      25.0
# 485                       True         1.0         4.0    14.0      30.0
# 486                       True         2.0         4.0    12.0     120.0
# 487                       True         2.0         4.0    14.0      60.0
#
#      playTimeUnit  fundedInSeconds  \
# 0               0              628
# 1               0             2716
# 2               1            56442
# 3               0          2409627
# 4               0            14439
# ..            ...              ...
# 483             0                0
# 484             0                0
# 485             0                0
# 486             0                0
# 487             0                0
#
#                                               imageUrl  \
# 0    https://imgcdn.gamefound.com/projectimage/proj...
# 1    https://imgcdn.gamefound.com/projectimage/proj...
# 2    https://imgcdn.gamefound.com/projectimage/proj...
# 3    https://imgcdn.gamefound.com/projectimage/proj...
# 4    https://imgcdn.gamefound.com/projectimage/proj...
# ..                                                 ...
# 483  https://imgcdn.gamefound.com/projectimage/proj...
# 484  https://imgcdn.gamefound.com/projectimage/proj...
# 485  https://imgcdn.gamefound.com/projectimage/proj...
# 486  https://imgcdn.gamefound.com/projectimage/proj...
# 487  https://imgcdn.gamefound.com/projectimage/proj...
#
#     pledgeManagerSoftCloseDeadline  \
# 0             2026-06-02T15:00:00Z
# 1             2026-06-01T14:00:00Z
# 2                              NaN
# 3                              NaN
# 4             2026-06-11T13:00:00Z
# ..                             ...
# 483                            NaN
# 484                            NaN
# 485                            NaN
# 486                            NaN
# 487                            NaN
#
#                                            projectTags  originalType
# 0    Exploration, Horror, Modern, Science Fiction, ...             1
# 1    History, Strategy, Wargame, Action, Collectibl...             1
# 2                           History, Strategy, Wargame             1
# 3              Card Game, Strategy, Party game, Family             1
# 4    Strategy, Resource management, Family, Worker ...             1
# ..                                                 ...           ...
# 483  Strategy, Wargame, Dice Game, Area Control, Co...             1
# 484                           Fantasy, Strategy, Humor             1
# 485      Dice Game, Multiplayer, Competitive, Campaign             1
# 486         Fantasy, Strategy, Terrain Building, Humor             1
# 487       Science Fiction, Area Control, Deck Building             1
#
# [488 rows x 23 columns]

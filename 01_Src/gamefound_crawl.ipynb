# %%
import requests
import pandas as pd
import time
from tqdm import tqdm

api_url = "https://gamefound.com/api/projectSearch/searchProjectsForCards"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

payload = {
    "creatorID": None,
    "creatorName": None,
    "sortType": 0,
    "term": "",
    "projectPhaseSearchTypes": [],
    "projectBenefits": [],
    "projectTags": [],
    "projectCatalogCategories": [11], #보드게임 카테고리 11번
    "playerAges": [],
    "playerCounts": [],
    "playTimes": [],
    "creator": {"creatorID": None, "name": None},
    "userCommunitySearchTypes": [],
    "source": 5,
    "pageIndex": 0 # 0페이지부터 시작 -> 이거 돌려야함
}

response = requests.post(api_url, headers=headers, json=payload)

# 응답, 전체 페이지 확인
if response.status_code == 200:
    data = response.json()
    total_page =data.get('projects').get('totalPageCount')
    print(f"전체 페이지 : {total_page}")
    print("성공")

else:
    print(f"실패 : {response.status_code}")

print("----------------------------------------------")
# 전체페이지 for문 ㄱㄱ / 총 108페이지

game_list = []

for page in tqdm(range(total_page)):
    print(f"{page} 페이지 시작")

    payload['pageIndex'] = page

    res = requests.post(api_url, headers=headers, json=payload)

    if res.status_code == 200:
        page_data = res.json()
        projects = page_data.get('projects').get('pagedItems')
        
        projects_data = page_data.get('projects')
        first_num = projects_data.get('firstItemNumber')
        last_num = projects_data.get('lastItemNumber')
        print(f"{first_num}~{last_num}개 진행중")
 
        for item in projects:
            game_dict = {
                'name': item.get('name'),                       # 프로젝트명
                'creator': item.get('creator').get('name'),     # 크리에이터 이름
                'currencySymbol': item.get('currencySymbol'),   # 화폐단위  ->  여러개임.....;;
                'campaignGoal': item.get('campaignGoal'),       # 목표 금액
                'fundsGathered': item.get('fundsGathered'),     # 모금액
                'backersCount': item.get('backersCount'),       # 후원자 수
                'campaignStart': item.get('campaignStart'),     # 시작일
                'campaignEnd': item.get('campaignEnd'),         # 마감일
                'description': item.get('shortDescription'),    # 설명
                'project_url': item.get('url'),                  # 프로젝트 링크 -> 이거로 추가 크롤링 해야함


                'phaseLabel' : item.get('phaseLabel'),                
                'enableBoardGameProperties': item.get('projectProperties').get('enableBoardGameProperties'), # ?
                'minPlayers': item.get('projectProperties').get('minPlayers'), # 최소인원
                'maxPlayers': item.get('projectProperties').get('maxPlayers'), # 최대인원
                'minAge': item.get('projectProperties').get('minAge'), # 연령제한
                'playTime': item.get('projectProperties').get('playTime'), # 플레이타임
                'playTimeDescription': item.get('projectProperties').get('playTimeDescription'), # 설명? 다 비어 있는거 같은데
                'playTimeUnit': item.get('projectProperties').get('playTimeUnit'), # ?

                'pledgeManagerAvailability': item.get('pledgeManagerAvailability'),
                'fundedInSeconds': item.get('fundedInSeconds'),
                'imageUrl': item.get('imageUrl'),
                'pledgeManagerSoftCloseDeadline': item.get('pledgeManagerSoftCloseDeadline'),
                'projectTags': item.get('projectTags'),
                'enableShippingOnlyMode': item.get('enableShippingOnlyMode'),
                'originalType': item.get('originalType'),
                        
            }
            game_list.append(game_dict)

    else:
        print(f"{page}페이지 실패")
        pass
    
    time.sleep(1.5)

df = pd.DataFrame(game_list)
# Out:
# 전체 페이지 : 108
# 성공
# ----------------------------------------------
#   0%|          | 0/108 [00:00<?, ?it/s]
# 0 페이지 시작
# 1~24개 진행중
#   1%|          | 1/108 [00:01<03:17,  1.85s/it]
# 1 페이지 시작
# 25~48개 진행중
#   2%|▏         | 2/108 [00:03<03:20,  1.89s/it]
# 2 페이지 시작
# 49~72개 진행중
#   3%|▎         | 3/108 [00:05<03:16,  1.87s/it]
# 3 페이지 시작
# 73~96개 진행중
#   4%|▎         | 4/108 [00:07<03:13,  1.86s/it]
# 4 페이지 시작
# 97~120개 진행중
#   5%|▍         | 5/108 [00:09<03:11,  1.86s/it]
# 5 페이지 시작
# 121~144개 진행중
#   6%|▌         | 6/108 [00:11<03:10,  1.86s/it]
# 6 페이지 시작
# 145~168개 진행중
#   6%|▋         | 7/108 [00:13<03:11,  1.89s/it]
# 7 페이지 시작
# 169~192개 진행중
#   7%|▋         | 8/108 [00:15<03:10,  1.90s/it]
# 8 페이지 시작
# 193~216개 진행중
#   8%|▊         | 9/108 [00:17<03:10,  1.92s/it]
# 9 페이지 시작
# 217~240개 진행중
#   9%|▉         | 10/108 [00:18<03:08,  1.92s/it]
# 10 페이지 시작
# 241~264개 진행중
#  10%|█         | 11/108 [00:20<03:05,  1.91s/it]
# 11 페이지 시작
# 265~288개 진행중
#  11%|█         | 12/108 [00:22<03:03,  1.91s/it]
# 12 페이지 시작
# 289~312개 진행중
#  12%|█▏        | 13/108 [00:24<02:58,  1.88s/it]
# 13 페이지 시작
# 313~336개 진행중
#  13%|█▎        | 14/108 [00:26<02:58,  1.90s/it]
# 14 페이지 시작
# 337~360개 진행중
#  14%|█▍        | 15/108 [00:28<02:59,  1.93s/it]
# 15 페이지 시작
# 361~384개 진행중
#  15%|█▍        | 16/108 [00:30<02:57,  1.93s/it]
# 16 페이지 시작
# 385~408개 진행중
#  16%|█▌        | 17/108 [00:32<02:54,  1.92s/it]
# 17 페이지 시작
# 409~432개 진행중
#  17%|█▋        | 18/108 [00:34<02:51,  1.91s/it]
# 18 페이지 시작
# 433~456개 진행중
#  18%|█▊        | 19/108 [00:36<02:48,  1.89s/it]
# 19 페이지 시작
# 457~480개 진행중
#  19%|█▊        | 20/108 [00:37<02:46,  1.89s/it]
# 20 페이지 시작
# 481~504개 진행중
#  19%|█▉        | 21/108 [00:39<02:44,  1.90s/it]
# 21 페이지 시작
# 505~528개 진행중
#  20%|██        | 22/108 [00:41<02:42,  1.89s/it]
# 22 페이지 시작
# 529~552개 진행중
#  21%|██▏       | 23/108 [00:43<02:41,  1.89s/it]
# 23 페이지 시작
# 553~576개 진행중
#  22%|██▏       | 24/108 [00:45<02:38,  1.89s/it]
# 24 페이지 시작
# 577~600개 진행중
#  23%|██▎       | 25/108 [00:47<02:37,  1.90s/it]
# 25 페이지 시작
# 601~624개 진행중
#  24%|██▍       | 26/108 [00:49<02:35,  1.90s/it]
# 26 페이지 시작
# 625~648개 진행중
#  25%|██▌       | 27/108 [00:51<02:33,  1.90s/it]
# 27 페이지 시작
# 649~672개 진행중
#  26%|██▌       | 28/108 [00:53<02:32,  1.91s/it]
# 28 페이지 시작
# 673~696개 진행중
#  27%|██▋       | 29/108 [00:55<02:30,  1.91s/it]
# 29 페이지 시작
# 697~720개 진행중
#  28%|██▊       | 30/108 [00:56<02:28,  1.90s/it]
# 30 페이지 시작
# 721~744개 진행중
#  29%|██▊       | 31/108 [00:58<02:27,  1.92s/it]
# 31 페이지 시작
# 745~768개 진행중
#  30%|██▉       | 32/108 [01:00<02:24,  1.90s/it]
# 32 페이지 시작
# 769~792개 진행중
#  31%|███       | 33/108 [01:02<02:21,  1.89s/it]
# 33 페이지 시작
# 793~816개 진행중
#  31%|███▏      | 34/108 [01:04<02:20,  1.89s/it]
# 34 페이지 시작
# 817~840개 진행중
#  32%|███▏      | 35/108 [01:06<02:18,  1.90s/it]
# 35 페이지 시작
# 841~864개 진행중
#  33%|███▎      | 36/108 [01:08<02:17,  1.90s/it]
# 36 페이지 시작
# 865~888개 진행중
#  34%|███▍      | 37/108 [01:10<02:15,  1.91s/it]
# 37 페이지 시작
# 889~912개 진행중
#  35%|███▌      | 38/108 [01:12<02:13,  1.91s/it]
# 38 페이지 시작
# 913~936개 진행중
#  36%|███▌      | 39/108 [01:14<02:11,  1.91s/it]
# 39 페이지 시작
# 937~960개 진행중
#  37%|███▋      | 40/108 [01:16<02:10,  1.92s/it]
# 40 페이지 시작
# 961~984개 진행중
#  38%|███▊      | 41/108 [01:17<02:08,  1.92s/it]
# 41 페이지 시작
# 985~1008개 진행중
#  39%|███▉      | 42/108 [01:19<02:06,  1.92s/it]
# 42 페이지 시작
# 1009~1032개 진행중
#  40%|███▉      | 43/108 [01:21<02:04,  1.92s/it]
# 43 페이지 시작
# 1033~1056개 진행중
#  41%|████      | 44/108 [01:23<02:03,  1.92s/it]
# 44 페이지 시작
# 1057~1080개 진행중
#  42%|████▏     | 45/108 [01:25<02:00,  1.92s/it]
# 45 페이지 시작
# 1081~1104개 진행중
#  43%|████▎     | 46/108 [01:27<01:59,  1.92s/it]
# 46 페이지 시작
# 1105~1128개 진행중
#  44%|████▎     | 47/108 [01:29<01:57,  1.93s/it]
# 47 페이지 시작
# 1129~1152개 진행중
#  44%|████▍     | 48/108 [01:31<01:55,  1.92s/it]
# 48 페이지 시작
# 1153~1176개 진행중
#  45%|████▌     | 49/108 [01:33<01:53,  1.92s/it]
# 49 페이지 시작
# 1177~1200개 진행중
#  46%|████▋     | 50/108 [01:35<01:51,  1.92s/it]
# 50 페이지 시작
# 1201~1224개 진행중
#  47%|████▋     | 51/108 [01:37<01:49,  1.92s/it]
# 51 페이지 시작
# 1225~1248개 진행중
#  48%|████▊     | 52/108 [01:39<01:48,  1.93s/it]
# 52 페이지 시작
# 1249~1272개 진행중
#  49%|████▉     | 53/108 [01:41<01:46,  1.94s/it]
# 53 페이지 시작
# 1273~1296개 진행중
#  50%|█████     | 54/108 [01:43<01:44,  1.94s/it]
# 54 페이지 시작
# 1297~1320개 진행중
#  51%|█████     | 55/108 [01:44<01:42,  1.94s/it]
# 55 페이지 시작
# 1321~1344개 진행중
#  52%|█████▏    | 56/108 [01:46<01:40,  1.93s/it]
# 56 페이지 시작
# 1345~1368개 진행중
#  53%|█████▎    | 57/108 [01:48<01:38,  1.93s/it]
# 57 페이지 시작
# 1369~1392개 진행중
#  54%|█████▎    | 58/108 [01:50<01:36,  1.93s/it]
# 58 페이지 시작
# 1393~1416개 진행중
#  55%|█████▍    | 59/108 [01:52<01:34,  1.93s/it]
# 59 페이지 시작
# 1417~1440개 진행중
#  56%|█████▌    | 60/108 [01:54<01:32,  1.94s/it]
# 60 페이지 시작
# 1441~1464개 진행중
#  56%|█████▋    | 61/108 [01:56<01:30,  1.93s/it]
# 61 페이지 시작
# 1465~1488개 진행중
#  57%|█████▋    | 62/108 [01:58<01:28,  1.93s/it]
# 62 페이지 시작
# 1489~1512개 진행중
#  58%|█████▊    | 63/108 [02:00<01:26,  1.92s/it]
# 63 페이지 시작
# 1513~1536개 진행중
#  59%|█████▉    | 64/108 [02:02<01:25,  1.94s/it]
# 64 페이지 시작
# 1537~1560개 진행중
#  60%|██████    | 65/108 [02:04<01:23,  1.94s/it]
# 65 페이지 시작
# 1561~1584개 진행중
#  61%|██████    | 66/108 [02:06<01:21,  1.93s/it]
# 66 페이지 시작
# 1585~1608개 진행중
#  62%|██████▏   | 67/108 [02:08<01:18,  1.92s/it]
# 67 페이지 시작
# 1609~1632개 진행중
#  63%|██████▎   | 68/108 [02:10<01:16,  1.92s/it]
# 68 페이지 시작
# 1633~1656개 진행중
#  64%|██████▍   | 69/108 [02:11<01:14,  1.92s/it]
# 69 페이지 시작
# 1657~1680개 진행중
#  65%|██████▍   | 70/108 [02:13<01:12,  1.92s/it]
# 70 페이지 시작
# 1681~1704개 진행중
#  66%|██████▌   | 71/108 [02:15<01:10,  1.92s/it]
# 71 페이지 시작
# 1705~1728개 진행중
#  67%|██████▋   | 72/108 [02:17<01:08,  1.91s/it]
# 72 페이지 시작
# 1729~1752개 진행중
#  68%|██████▊   | 73/108 [02:19<01:07,  1.92s/it]
# 73 페이지 시작
# 1753~1776개 진행중
#  69%|██████▊   | 74/108 [02:21<01:05,  1.92s/it]
# 74 페이지 시작
# 1777~1800개 진행중
#  69%|██████▉   | 75/108 [02:23<01:03,  1.92s/it]
# 75 페이지 시작
# 1801~1824개 진행중
#  70%|███████   | 76/108 [02:25<01:01,  1.92s/it]
# 76 페이지 시작
# 1825~1848개 진행중
#  71%|███████▏  | 77/108 [02:27<00:59,  1.91s/it]
# 77 페이지 시작
# 1849~1872개 진행중
#  72%|███████▏  | 78/108 [02:29<00:57,  1.92s/it]
# 78 페이지 시작
# 1873~1896개 진행중
#  73%|███████▎  | 79/108 [02:31<00:55,  1.91s/it]
# 79 페이지 시작
# 1897~1920개 진행중
#  74%|███████▍  | 80/108 [02:33<00:53,  1.91s/it]
# 80 페이지 시작
# 1921~1944개 진행중
#  75%|███████▌  | 81/108 [02:34<00:51,  1.92s/it]
# 81 페이지 시작
# 1945~1968개 진행중
#  76%|███████▌  | 82/108 [02:36<00:50,  1.93s/it]
# 82 페이지 시작
# 1969~1992개 진행중
#  77%|███████▋  | 83/108 [02:38<00:48,  1.92s/it]
# 83 페이지 시작
# 1993~2016개 진행중
#  78%|███████▊  | 84/108 [02:40<00:46,  1.93s/it]
# 84 페이지 시작
# 2017~2040개 진행중
#  79%|███████▊  | 85/108 [02:42<00:44,  1.93s/it]
# 85 페이지 시작
# 2041~2064개 진행중
#  80%|███████▉  | 86/108 [02:44<00:42,  1.94s/it]
# 86 페이지 시작
# 2065~2088개 진행중
#  81%|████████  | 87/108 [02:46<00:40,  1.94s/it]
# 87 페이지 시작
# 2089~2112개 진행중
#  81%|████████▏ | 88/108 [02:48<00:38,  1.93s/it]
# 88 페이지 시작
# 2113~2136개 진행중
#  82%|████████▏ | 89/108 [02:50<00:36,  1.93s/it]
# 89 페이지 시작
# 2137~2160개 진행중
#  83%|████████▎ | 90/108 [02:52<00:34,  1.92s/it]
# 90 페이지 시작
# 2161~2184개 진행중
#  84%|████████▍ | 91/108 [02:54<00:32,  1.91s/it]
# 91 페이지 시작
# 2185~2208개 진행중
#  85%|████████▌ | 92/108 [02:56<00:30,  1.92s/it]
# 92 페이지 시작
# 2209~2232개 진행중
#  86%|████████▌ | 93/108 [02:58<00:28,  1.91s/it]
# 93 페이지 시작
# 2233~2256개 진행중
#  87%|████████▋ | 94/108 [02:59<00:26,  1.91s/it]
# 94 페이지 시작
# 2257~2280개 진행중
#  88%|████████▊ | 95/108 [03:01<00:24,  1.92s/it]
# 95 페이지 시작
# 2281~2304개 진행중
#  89%|████████▉ | 96/108 [03:03<00:22,  1.90s/it]
# 96 페이지 시작
# 2305~2328개 진행중
#  90%|████████▉ | 97/108 [03:05<00:21,  1.91s/it]
# 97 페이지 시작
# 2329~2352개 진행중
#  91%|█████████ | 98/108 [03:07<00:19,  1.91s/it]
# 98 페이지 시작
# 2353~2376개 진행중
#  92%|█████████▏| 99/108 [03:09<00:17,  1.93s/it]
# 99 페이지 시작
# 2377~2400개 진행중
#  93%|█████████▎| 100/108 [03:11<00:15,  1.92s/it]
# 100 페이지 시작
# 2401~2424개 진행중
#  94%|█████████▎| 101/108 [03:13<00:13,  1.94s/it]
# 101 페이지 시작
# 2425~2448개 진행중
#  94%|█████████▍| 102/108 [03:15<00:11,  1.93s/it]
# 102 페이지 시작
# 2449~2472개 진행중
#  95%|█████████▌| 103/108 [03:17<00:09,  1.93s/it]
# 103 페이지 시작
# 2473~2496개 진행중
#  96%|█████████▋| 104/108 [03:19<00:07,  1.94s/it]
# 104 페이지 시작
# 2497~2520개 진행중
#  97%|█████████▋| 105/108 [03:21<00:05,  1.93s/it]
# 105 페이지 시작
# 2521~2544개 진행중
#  98%|█████████▊| 106/108 [03:23<00:03,  1.94s/it]
# 106 페이지 시작
# 2545~2568개 진행중
#  99%|█████████▉| 107/108 [03:25<00:01,  1.94s/it]
# 107 페이지 시작
# 2569~2590개 진행중
# 100%|██████████| 108/108 [03:27<00:00,  1.92s/it]

# %%
df.head()
# Out:
#                             name           creator currencySymbol  \
# 0                     Bloodstone  Druid City Games              $
# 1                         Aeolis        Meeple Pug              €
# 2                         A Life     Skellig Games              €
# 3  Growing Season Deluxe Edition         Undigital              €
# 4      Stonesaga Second Printing  Open Owl Studios              $
#
#    campaignGoal  fundsGathered  backersCount         campaignStart  \
# 0       50000.0       93311.94           469  2026-06-02T13:00:00Z
# 1           NaN       33413.90           305  2026-06-02T15:00:00Z
# 2       10000.0       22326.05           197  2026-06-02T15:00:00Z
# 3        8000.0       14881.70           352  2026-06-02T16:00:00Z
# 4       25000.0      154683.02          1788  2026-05-26T15:00:00Z
#
#             campaignEnd                                        description  \
# 0  2026-06-19T22:00:00Z  Bloodstone throws you into Vanira’s deadly are...
# 1  2026-06-11T19:00:00Z  Aeolis is a fully cooperative kingdom-building...
# 2  2026-06-25T18:00:00Z  In "A Life" 1-4 players play through a lifetim...
# 3  2026-06-22T22:00:00Z  Turn a quiet field into a thriving farm in thi...
# 4  2026-06-20T00:00:00Z  Build a civilization across epochs in a cooper...
#
#                                          project_url  ... playTime  \
# 0  https://gamefound.com:443/en/projects/druid-ci...  ...     60.0
# 1  https://gamefound.com:443/en/projects/meeple-p...  ...     60.0
# 2  https://gamefound.com:443/en/projects/skellig-...  ...     60.0
# 3  https://gamefound.com:443/en/projects/undigita...  ...     30.0
# 4  https://gamefound.com:443/en/projects/oomm-gam...  ...     90.0
#
#    playTimeDescription  playTimeUnit  pledgeManagerAvailability  \
# 0                 None             0                        NaN
# 1                 None             0                        NaN
# 2                 None             0                        NaN
# 3                 None             0                        NaN
# 4                 None             0                        NaN
#
#    fundedInSeconds                                           imageUrl  \
# 0             7770  https://imgcdn.gamefound.com/projectimage/proj...
# 1                0  https://imgcdn.gamefound.com/projectimage/proj...
# 2             3756  https://imgcdn.gamefound.com/projectimage/proj...
# 3             4725  https://imgcdn.gamefound.com/projectimage/proj...
# 4             1764  https://imgcdn.gamefound.com/projectimage/proj...
#
#   pledgeManagerSoftCloseDeadline  \
# 0                           None
# 1                           None
# 2                           None
# 3                           None
# 4                           None
#
#                                          projectTags  enableShippingOnlyMode  \
# 0  [{'projectTagID': 1, 'isSystem': False, 'isVis...                    None
# 1  [{'projectTagID': 18, 'isSystem': False, 'isVi...                    None
# 2  [{'projectTagID': 30, 'isSystem': False, 'isVi...                    None
# 3  [{'projectTagID': 2, 'isSystem': False, 'isVis...                    None
# 4  [{'projectTagID': 1, 'isSystem': False, 'isVis...                    None
#
#    originalType
# 0             1
# 1             2
# 2             1
# 3             1
# 4             1
#
# [5 rows x 25 columns]

# %%
import os
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)

df.to_csv(parent_dir+"\\02_Data\\raw\\gamefound_list.csv", index=True, encoding="utf-8-sig")
